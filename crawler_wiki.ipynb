# %%
import requests
from bs4 import BeautifulSoup, Tag
from urllib.parse import urljoin, urlparse, urldefrag
import time
import re
import wikipediaapi
from fake_useragent import UserAgent
import wikipediaapi
import urllib.parse
import time
import re

# %%
ua = UserAgent()
USER_AGENT = ua.random

REQUEST_TIMEOUT = 10  
CRAWL_DELAY = 1 
SESSION = requests.Session()
SESSION.headers.update({"User-Agent": ua.random})
# MAX_PAGES_PER_DOMAIN = 100

# %%
def get_page_html_from_api(page_title, lang):
    
    api_url = f"https://{lang}.wikipedia.org/w/api.php"
    params = {
        "action": "parse",
        "page": page_title,
        "prop": "text",       
        "format": "json",
        "disabletoc": True,    
        "disableeditsection": True
    }
    try:
        response = SESSION.get(url=api_url, params=params)
        response.raise_for_status()
        data = response.json()
        if "parse" in data and "text" in data["parse"] and "*" in data["parse"]["text"]:
            return data["parse"]["text"]["*"]
        else:
            print(f"Could not find parsed text for '{page_title}' on {lang}.wikipedia.org")
            print(f"API Response: {data}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request error fetching HTML for '{page_title}': {e}")
        return None

# %%
def get_wiki_lang_and_title_from_url(url):
    try:
        parsed_url = urllib.parse.urlparse(url)
        hostname = parsed_url.hostname # 'vi'
        path_parts = parsed_url.path.strip('/').split('/') # ['wiki', 'title']

        lang_match = re.match(r"([a-z]{2,3}(?:-[a-z]+)?)", hostname)
        lang = lang_match.group(1)

        if len(path_parts) >= 2 and path_parts[0].lower() == 'wiki':
            page_title_encoded = path_parts[1]
            page_title = urllib.parse.unquote(page_title_encoded).replace('_', ' ')
            return lang, page_title
        else:
            print(f"Error: URL path does not match expected '/wiki/Page_Title' structure: {parsed_url.path}")
            return None, None

    except Exception as e:
        print(f"Error parsing {url}': {e}")
        return None, None

# %%
def process_monument_links_from_table(seed_url):
    lang, seed_page_title = get_wiki_lang_and_title_from_url(seed_url)


    
    monument_column_header="Di tích"

    # Get the HTML of the seed page
    page_html_content = get_page_html_from_api(seed_page_title, lang)


    soup = BeautifulSoup(page_html_content, 'lxml')
    monument_titles = set() 

    # Find tables 
    tables = soup.find_all('table', class_='wikitable')
    if not tables:
        print("No 'wikitable' found on the page.")


    found_monument_column = False
    for table in tables:
        headers = [th.get_text(strip=True) for th in table.find_all('th')]
        monument_col_idx = -1

        for i, header_text in enumerate(headers):
            if monument_column_header.lower() in header_text.lower(): 
                monument_col_idx = i
                found_monument_column = True
                break

        if monument_col_idx != -1:
            print(f"Found '{monument_column_header}' column at index {monument_col_idx} in a table.")
            # Iterate through rows of this table
            for row in table.find_all('tr'):
                cells = row.find_all(['td', 'th']) #
                if len(cells) > monument_col_idx:
                    monument_cell = cells[monument_col_idx]
                    # Find all a tags 
                    for link_tag in monument_cell.find_all('a', href=True):
                        href = link_tag['href']
                        # Check internal Wikipedia link
                        if href.startswith('/wiki/') and ':' not in href[6:]:
                            link_title_encoded = href.split('/wiki/')[-1]
                            # Avoid links to the same page
                            if '#' not in link_title_encoded:
                                link_title = urllib.parse.unquote(link_title_encoded).replace('_', ' ')
                                #filter out red links
                                if 'class' not in link_tag.attrs or 'new' not in link_tag['class']:
                                    monument_titles.add(link_title)

    


    if not monument_titles:
        print(f"No monument links found in the '{monument_column_header}' column.")
        return

    print(f"\nFound {len(monument_titles)} unique potential monument titles from the table column.")


    return monument_titles, lang

# vietnamese_monuments_url = 'https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_Di_t%C3%ADch_qu%E1%BB%91c_gia_Vi%E1%BB%87t_Nam'

# sec_url = 'https://vi.wikipedia.org/wiki/Di_t%C3%ADch_qu%E1%BB%91c_gia_%C4%91%E1%BA%B7c_bi%E1%BB%87t_(Vi%E1%BB%87t_Nam)'
# # The header text for the monument column on the Vietnamese page is "Di tích"
# monument_titles = process_monument_links_from_table(vietnamese_monuments_url)

# %%
exclude_section_titles_lower = [
"xem thêm", "chú thích", "liên kết ngoài", "tham khảo", "đọc thêm",
"gallery", "hình ảnh", "notes", "references", "external links", "see also",
"bibliography", "sources" 
]
def get_clean_text_from_wiki_page(page_title,lang,wiki_api_instance):

    page = wiki_api_instance.page(page_title)

    if not page.exists():
        print(f"  Page '{page_title}' ({lang}) does not exist via wikipediaapi.")
        return ""

    formatted_text_parts = []


    for section in page.sections:
        section_title_cleaned = section.title.strip()
        if section_title_cleaned.lower() not in exclude_section_titles_lower:
            sec_text = section.text.strip()

            if sec_text: 
                formatted_text_parts.append(f"# {section_title_cleaned}\n{sec_text}")

    full_text = "\n\n".join(formatted_text_parts).strip()
    
    return full_text

def fetch_monument_page_texts(
    monument_titles: set,
    lang: str,
    max_pages_to_fetch: int = None,
    user_agent_for_content: str = USER_AGENT,
):
    if not monument_titles:
        print("No monument titles provided to fetch texts for.")
        return []

    print(f"\nFetching text for up to {max_pages_to_fetch if max_pages_to_fetch else len(monument_titles)} monument pages on {lang}.wikipedia.org...")
    
    wiki_api = wikipediaapi.Wikipedia(
        language=lang,
        user_agent=user_agent_for_content,
        extract_format=wikipediaapi.ExtractFormat.WIKI
    )

    all_monument_data = []
    count = 0
    for title in monument_titles:
        if max_pages_to_fetch is not None and count >= max_pages_to_fetch:
            print(f"Reached max pages limit of {max_pages_to_fetch}.")
            break
        
        print(f"  Fetching for: '{title}'...")
        page_text = get_clean_text_from_wiki_page(
            title,
            lang,
            wiki_api,
        )

        if page_text:
            all_monument_data.append({
                "title": title,
                "language": lang,
                "url": f"https://{lang}.wikipedia.org/wiki/{urllib.parse.quote(title.replace(' ', '_'))}",
                "text_content": page_text
            })
        else:
            print(f"  No text extracted for '{title}'.")
        
        count += 1
        time.sleep(0.5)

    return all_monument_data

# %%
import json

seed_url ='https://vi.wikipedia.org/wiki/Di_t%C3%ADch_qu%E1%BB%91c_gia_%C4%91%E1%BA%B7c_bi%E1%BB%87t_(Vi%E1%BB%87t_Nam)'
max_pages_to_process_from_list = 620
output_json_file = "monument_database_no_summary_2.json"

monument_titles_set, site_lang = process_monument_links_from_table(seed_url)

if monument_titles_set and site_lang:
    print(f"\n--- Successfully extracted {len(monument_titles_set)} titles")


    print(f"\nStep 2: Fetching text content for up to {max_pages_to_process_from_list or len(monument_titles_set)} monument pages...")
    extracted_data = fetch_monument_page_texts(
        monument_titles=monument_titles_set,
        lang=site_lang,
        max_pages_to_fetch=max_pages_to_process_from_list,
        user_agent_for_content=USER_AGENT
    )


    try:
        with open(output_json_file, 'a', encoding='utf-8') as f:
            json.dump(extracted_data, f, ensure_ascii=False, indent=4)
        print(f"\nSaved detailed data for {len(extracted_data)} monuments to '{output_json_file}'")
    except IOError as e:
        print(f"Error saving data to JSON file: {e}")

else:
    print("\nCould not extract monument titles from the seed URL. Pipeline halted.")
# Out:
# Found 'Di tích' column at index 1 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
# Found 'Di tích' column at index 0 in a table.
#
# Found 132 unique potential monument titles from the table column.
#
# --- Successfully extracted 132 titles
#
# Step 2: Fetching text content for up to 620 monument pages...
#
# Fetching text for up to 620 monument pages on vi.wikipedia.org...
#   Fetching text for: 'Quần thể di tích danh thắng Yên Tử'...
#   Fetching text for: 'Đền Hát Môn'...
#   Fetching text for: 'Tháp Nhạn'...
#   No text extracted for 'Tháp Nhạn'.
#   Fetching text for: 'Núi Trường Lệ'...
#   Fetching text for: 'Đình Thổ Tang'...
#   Fetching text for: 'Khu lưu niệm Chủ tịch Tôn Đức Thắng'...
#   Fetching text for: 'Khởi nghĩa Bắc Sơn'...
#   No text extracted for 'Khởi nghĩa Bắc Sơn'.
#   Fetching text for: 'Thành cổ Quảng Trị'...
#   Fetching text for: 'Đình Đại Phùng'...
#   Fetching text for: 'Mộ cự thạch Hàng Gòn'...
#   Fetching text for: 'Tháp Po Nagar'...
#   Fetching text for: 'Đình Đình Bảng'...
#   Fetching text for: 'Đền Hùng'...
#   Fetching text for: 'Đền Trần Thương'...
#   Fetching text for: 'Đền Trần (Nam Định)'...
#   Fetching text for: 'Tuyên ngôn độc lập (Việt Nam Dân chủ Cộng hòa)'...
#   Fetching text for: 'Đền An Xá'...
#   No text extracted for 'Đền An Xá'.
#   Fetching text for: 'Thành nhà Hồ'...
#   Fetching text for: 'Chùa Keo Hành Thiện'...
#   Fetching text for: 'Ruộng bậc thang Mù Cang Chải'...
#   Fetching text for: 'Thánh địa Cát Tiên'...
#   Fetching text for: 'Nhà tù Sơn La'...
#   Fetching text for: 'Rừng Trần Hưng Đạo'...
#   Fetching text for: 'Đền Lý Bát Đế'...
#   Fetching text for: 'Chùa Bổ Đà'...
#   Fetching text for: 'Chùa Hương'...
#   Fetching text for: 'Khu di tích Côn Sơn – Kiếp Bạc'...
#   Fetching text for: 'Trung ương cục miền Nam'...
#   Fetching text for: 'Đền thờ Lê Hoàn'...
#   No text extracted for 'Đền thờ Lê Hoàn'.
#   Fetching text for: 'Hồ Ba Bể'...
#   Fetching text for: 'Chùa Dâu'...
#   Fetching text for: 'Đình Chèm'...
#   Fetching text for: 'Gò Tháp'...
#   Fetching text for: 'Đường Lâm'...
#   Fetching text for: 'Thương cảng Vân Đồn'...
#   Fetching text for: 'Nhà đày Buôn Ma Thuột'...
#   Fetching text for: 'Khu bảo tồn thiên nhiên Na Hang'...
#   Fetching text for: 'Di chỉ Đồng Đậu'...
#   Fetching text for: 'Đường Trường Sơn'...
#   Fetching text for: 'Chùa Kim Liên'...
#   No text extracted for 'Tháp Dương Long'.
#   Fetching text for: 'Văn miếu Mao Điền'...
#   Fetching text for: 'Văn hóa Đông Sơn'...
#   Fetching text for: 'Tháp Po Klong Garai'...
#   Fetching text for: 'Chùa Bút Tháp'...
#   Fetching text for: 'Lăng Nguyễn Đình Chiểu'...
#   Fetching text for: 'Đình Tường Phiêu'...
#   Fetching text for: 'Tháp Vĩnh Hưng'...
#   Fetching text for: 'Tây Sơn Tam Kiệt'...
#   Fetching text for: 'Khu di tích khởi nghĩa Yên Thế'...
#   Fetching text for: 'Chùa Đậu (Hà Nội)'...
#   Fetching text for: 'Chùa Tây Phương'...
#   Fetching text for: 'Chiến dịch Biên giới'...
#   Fetching text for: 'Phố cổ Hội An'...
#   Fetching text for: 'Khu di chỉ văn hóa Sa Huỳnh'...
#   Fetching text for: 'Quần thể di tích Cố đô Huế'...
#   No text extracted for 'Quần thể di tích Cố đô Huế'.
#   Fetching text for: 'Mai Hắc Đế'...
#   Fetching text for: 'Địa đạo Củ Chi'...
#   Fetching text for: 'Gành Đá Đĩa'...
#   Fetching text for: 'An toàn khu II'...
#   Fetching text for: 'Hồ Hoàn Kiếm'...
#   Fetching text for: 'Chùa Keo'...
#   No text extracted for 'Chùa Keo'.
#   Fetching text for: 'Tam Cốc - Bích Động'...
#   Fetching text for: 'Chùa Đọi Sơn'...
#   Fetching text for: 'Chùa Thầy'...
#   Fetching text for: 'Hang Con Moong'...
#   Fetching text for: 'Đền Cửa Ông'...
#   Fetching text for: 'ATK'...
#   Fetching text for: 'Phật viện Đồng Dương'...
#   Fetching text for: 'Chùa Thái Lạc'...
#   Fetching text for: 'Đền Ngọc Sơn'...
#   Fetching text for: 'Đình Hạ Hiệp'...
#   Fetching text for: 'Chùa Phổ Minh'...
#   Fetching text for: 'Lam Kinh'...
#   Fetching text for: 'Óc Eo'...
#   Fetching text for: 'Vườn quốc gia Cát Tiên'...
#   Fetching text for: 'Chùa Vĩnh Nghiêm (Bắc Giang)'...
#
# --- Successfully fetched text for 123 monument pages ---
#
# --- Sample Entry 1 ---
# Title: Quần thể di tích danh thắng Yên Tử
# URL: https://vi.wikipedia.org/wiki/Qu%E1%BA%A7n_th%E1%BB%83_di_t%C3%ADch_danh_th%E1%BA%AFng_Y%C3%AAn_T%E1%BB%AD
#
# Formatted Text Content (first 300 chars):
# # Tổng quan
# Quần thể di tích và danh thắng Yên Tử – Vĩnh Nghiêm – Côn Sơn, Kiếp Bạc gồm 5 khu di tích: danh thắng Yên Tử; nhà Trần Đông Triều; Côn Sơn Kiếp Bạc; chiến thắng Bạch Đằng; Quần thể di tích An Phụ - Kính Chủ - Nhẫm Dương; 3 di tích khác cũng nằm trong danh sách đề cử: chùa Bồ Đà, chùa Vĩn...
#
# --- Sample Entry 2 ---
# Title: Đền Hát Môn
# URL: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%81n_H%C3%A1t_M%C3%B4n
#
# Formatted Text Content (first 300 chars):
# # Lịch sử
 của nghĩa quân.\nĐến năm 1762, thành Bản Phủ được xây dựng xong.\nTrong khoảng thời gian từ 1758-1762, nghĩa quân Hoàng Công Chất vừa xây dựng thành Bản Phủ vùa hoạt động ra khắp 10 châu của phủ An Tây, phía bắc đến tận vùng Vân Nam (Trung Quốc), phía nam đến tận Ninh Bình, Hòa Bình, Thanh Hóa ngày nay.\nNăm 1769, quân Trịnh tấn công Mường Thanh, xóa bỏ vùng cát cứ của Hoàng Công Toản (con Hoàng Công Chất), đánh úp và phá hủy thành Bản Phủ.\n\nKiến trúc\nThành trì: rộng hơn 80 mẫu, dựa lưng vào sông Nậm Rốm; chân thành rộng 15m, mặt thành rộng 5m, cao 15m; tường thành đắp bằng đất; trồng 3 vạn gốc tre gai đem từ miền Tây Thanh Hóa lên; hào sâu rộng 4-5 thước. Có thuyết nói rằng trên mặt thành ngựa, voi có thể đi lại được. Thành có các cửa: tiền, hậu, tả, hữu. Mỗi cửa có đồn cao và vọng gác...\nĐền thờ Hoàng Công Chất: được xây ở trung tâm thành, thờ họ Hoàng và 6 thủ lĩnh nghĩa quân. Đền còn là nơi tín ngưỡng của nhân dân trong ngày rằm, đầu xuân năm mới, nhất là ngày lễ hội truyền thống vào các ngày 24, 25 tháng Hai âm lịch hàng năm.\n\nĐiểm giống với trận Điện Biên Phủ\nTrong bối cảnh xây dựng thành Bản Phủ có một số điểm khá giống với câu chuyện 200 năm sau:\n\nTrận đánh quyết định của quân Hoàng Công Chất với giặc Phẻ diễn ra vào năm 1754, chiến dịch Điện Biên Phủ diễn ra vào năm 1954. Cả hai trận này đều hoàn thành việc giải phóng miền Tây Bắc khỏi quân xâm lược.\nGiặc Phẻ chúng thảm sát dân Việt ở Tông Khao (đồng xương trắng), còn quân Pháp có vụ thảm sát ở Noong Nhai.\nHoàng Công Chất quê ở Thái Bình. 200 năm sau, Đại đội trưởng Tạ Quốc Luật thuộc Đại đoàn 312, người gương cao ngọn cờ chiến thắng trên nóc hầm Đờ Cát trong trận địa Điện Biên Phủ cũng là người quê Thái Bình.\n\nXem thêm\nHoàng Công Chất\n\nChú thích\n\n\n== Liên kết ngoài =='

# %%
categories = page.categories
for title in sorted(categories.keys()):
    print("%s: %s" % (title, categories[title]))
# Out:
# Thể loại:Bản mẫu webarchive dùng liên kết wayback: Thể loại:Bản mẫu webarchive dùng liên kết wayback (lang: vi, variant: None, id: ??, ns: 14)
# Thể loại:Di tích quốc gia Việt Nam: Thể loại:Di tích quốc gia Việt Nam (lang: vi, variant: None, id: ??, ns: 14)
# Thể loại:Di tích tại Điện Biên: Thể loại:Di tích tại Điện Biên (lang: vi, variant: None, id: ??, ns: 14)
# Thể loại:Thành cổ Việt Nam: Thể loại:Thành cổ Việt Nam (lang: vi, variant: None, id: ??, ns: 14)
# Thể loại:Tọa độ không có sẵn trên Wikidata: Thể loại:Tọa độ không có sẵn trên Wikidata (lang: vi, variant: None, id: ??, ns: 14)
# Thể loại:Điện Biên: Thể loại:Điện Biên (lang: vi, variant: None, id: ??, ns: 14)

# %%
page2 = wiki_wiki.page('Thành Bát Quái')
exclude_titles_lower = ["xem thêm", "chú thích", "liên kết ngoài", "tham khảo", "đọc thêm", "gallery", "hình ảnh"]
meaningful_text_parts = []
for section in page2.sections:
    if section.title.lower().strip() not in exclude_titles_lower:
        sec_text = section.text
        meaningful_text_parts.append(sec_text)
        print(f"Section: {section.title}\n{sec_text}\n")

full_meaningful_text = "\n\n".join(meaningful_text_parts)
# Out:
# Section: Lịch sử
# Tháng 8 năm Mậu Thân (7 tháng 9 năm 1788), lợi dụng khi quân Tây Sơn đang bận tái lập trật tự Bắc Hà và đánh quân Thanh, Nguyễn Ánh đánh chiếm được Sài Gòn và biến nơi đây thành cơ sở chống lại Tây Sơn.
# Hai năm sau, 1790, Nguyễn Ánh chọn đất Sài Gòn làm kinh đô, tên là Gia Định kinh; rồi ông nhờ hai người Pháp là Olivier de Puymanel (Việt danh là "Ông Tín") và Théodore Lebrun là 2 sĩ quan công binh người Pháp đi theo giám mục Bá Đa Lộc vẽ họa đồ thành theo kiểu châu Âu kết hợp với bản vẽ quy hoạch của Trần Văn Học. Thành được xây dưới sự chỉ huy của Tôn Thất Hội với gần 30.000 dân phu được huy động, với tường thành cao mười lăm thước mộc, tính ra lối bốn thước tây lẻ tám tấc (khoảng 4 m 8), toàn bằng đá ong Biên Hòa kiểu "lục lăng", nhằm củng cố chân đứng của mình trên đất Gia Định.
# Tháng 7 năm Nhâm Tý (1792), vua Quang Trung Nguyễn Huệ của nhà Tây Sơn băng hà, triều Tây Sơn lục đục nội bộ và rơi vào khủng hoảng, Nguyễn Ánh nhanh chóng tổ chức phản công và ông đánh bại nhà Tây Sơn sau đó nhiều năm. Sau khi tiêu diệt nhà Tây Sơn, Nguyễn Ánh lên ngôi vua, hiệu là Gia Long, rồi dời kinh đô từ Gia Định kinh (Sài Gòn) về Huế.
# Năm 1811, kinh thành Huế được làm xong thì Gia Định kinh được đổi thành Gia Định thành (cao hơn cấp trấn) và trở thành thị sở của quan Tổng trấn Nam Kỳ.
# Đến đời vua Minh Mạng, năm 1830, Lê Văn Khôi, con nuôi của Lê Văn Duyệt, nổi loạn, đánh chiếm lấy thành Bát Quái và biến nơi đây thành căn cứ chính cho cuộc nổi dậy của mình từ năm 1833 đến 1835. Sau khi đánh bại Lê Văn Khôi rồi, vua Minh Mạng đã cho phá thành Bát Quái để lập thành Gia Định mới năm 1837. Chính vì sự phá hủy này mà thành Bát Quái còn bị gọi Gia Định phế thành.
# Xem thêm Cuộc nổi dậy Lê Văn Khôi
#
# Section: Kiến trúc và địa thế
# Thành Bát Quái này gần như hình bát giác, có tám cổng theo mẫu bát quái tượng trưng cho tứ phương chính cùng với các hướng phụ. Thành trải rộng từ Nam đến Bắc, từ đường Mac-Mahon (bây giờ là đường Nam Kỳ Khởi Nghĩa) tới bức tường thành đã bị phá (bây giờ là khu vực đường Đinh Tiên Hoàng và Tôn Đức Thắng) và từ Đông sang Tây, từ đường Espagne (bây giờ là đường Lê Thánh Tôn) đến đường Mọi (bây giờ là đường Nguyễn Đình Chiểu). Nguyễn Ánh đóng quân ở thành này suốt hai mươi hai năm, năm nào ông cũng đem quân đi đánh Tây Sơn khi gió mùa thuận lợi.
# Thành có 8 cửa, phía nam là cửa Càn Nguyên và cửa Li Minh, phía bắc là cửa Khôn Hậu và cửa Khảm Hiền, phía đông là cửa Chấn Hanh và cửa Cấm Chí, phía tây là cửa Tốn Thuận và cửa Đoài Duyệt. Thời Minh Mạng đổi tên các cửa: phía nam là cửa Gia Định và cửa Phiên An, phía bắc là cửa Củng Thần và cửa Vọng Thuyết, phía đông là cửa Phục Viễn và cửa Hoài Lai, phía tây là cửa Tĩnh Biên và cửa Tuyên Hóa.
# Các điểm dân cư, công trình kiến trúc hình thành từ tận khi những người Minh Hương đến đây vào khoảng năm 1680: công trình kiến trúc lúc này có là đồn lính, kho lương thảo, dinh quan trấn thủ như: kho Quản Thảo, dinh Tân Thuận, dinh Nặc Nộn, cùng một hệ thống đồn lính ngay cảng Bến Nghé. Các công trình tôn giáo và chợ búa phục vụ nhu cầu người dân, binh lính hình thành như chợ Điều Khiển, chùa Cây Mai. Đồng thời một số địa danh phản ánh sự hình thành điểm dân cư như Bầu Tròn, Thị Nghè, Đất Hộ cũng ra đời. Từ năm 1801, nhờ sự hỗ trợ của Pháp, Nguyễn Ánh đánh bại Tây Sơn, thành lập triều Nguyễn, thống nhất Việt Nam. Lê Văn Duyệt được cử làm Tổng trấn Nam Kỳ và trú đóng tại Sài Gòn. Các công trình chợ búa, cảng, cửa hàng. kho hàng, các khối ngành nghề thủ công… xung quanh thành Bát Quái phát triển theo, xoá đi những điểm chợ búa và thương mại cũ ngày xưa và phần thị được hình thành một cách tự phát. Vì tình hình bất ổn, nhiều người Hoa ở Hà Tiên, Định Quán cũng chạy về vùng Sài Gòn gần thành Bát Quái hình thành nên vùng Chợ Lớn, giao thông với thành Bát Quái bằng kênh Tàu Hủ và một con đường độc đạo. Số cư dân của thành năm 1819 là khoảng một trăm tám chục ngàn (180.000) dân bản địa và mười ngàn (10.000) người Trung Quốc.
# ------------------------------------------

# %%
def print_categorymembers(categorymembers, level=0, max_level=1):
    for c in categorymembers.values():
        print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
        if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
            print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)

cat = wiki_wiki.page("Category:Thành cổ Việt Nam")
print("Category members: Category:Thành cổ Việt Nam")
print_categorymembers(cat.categorymembers)
# Out:
# Category members: Category:Thành cổ Việt Nam
# *: Thành Bản Phủ (Điện Biên) (ns: 0)
# *: Thành Bình Định (ns: 0)
# *: Thành Bản Phủ (Cao Bằng) (ns: 0)
# *: Thành Bát Quái (ns: 0)
# *: Thành cổ Biên Hòa (ns: 0)
# *: Bình Lỗ (ns: 0)
# *: Đại đồn Chí Hòa (ns: 0)
# *: Thành Cổ Loa (ns: 0)
# *: Cổ Lũy (ns: 0)
# *: Cửa Bắc (Thành Hà Nội) (ns: 0)
# **: Thành Phụng (ns: 0)
# **: Thành Vĩnh Long (ns: 0)

# %%
def get_wiki_lang_and_title_from_url(url):
    try:
        parsed_url = urllib.parse.urlparse(url)
        hostname = parsed_url.hostname # 'vi'
        path_parts = parsed_url.path.strip('/').split('/') # ['wiki', 'title']

        lang_match = re.match(r"([a-z]{2,3}(?:-[a-z]+)?)", hostname)
        if not lang_match:
            print(f"Error: Could not extract language from hostname: {hostname}")
            return None, None
        lang = lang_match.group(1)

        if len(path_parts) >= 2 and path_parts[0].lower() == 'wiki':
            page_title_encoded = path_parts[1]
            page_title = urllib.parse.unquote(page_title_encoded).replace('_', ' ')
            return lang, page_title
        else:
            print(f"Error: URL path does not match expected '/wiki/Page_Title' structure: {parsed_url.path}")
            return None, None

    except Exception as e:
        print(f"Error parsing {url}': {e}")
        return None, None
    
get_wiki_lang_and_title_from_url('https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_Di_t%C3%ADch_qu%E1%BB%91c_gia_Vi%E1%BB%87t_Nam')
# Out:
# ('vi', 'Danh sách Di tích quốc gia Việt Nam')

# %%
def process_wikipedia_page_and_links(seed_url, max_links_to_process=5, text_chars_limit=200):
    """
    Fetches a Wikipedia page, then iterates through its internal links,
    printing the title and summary/text of each linked page.
    """
    lang, seed_page_title = get_wiki_lang_and_title_from_url(seed_url)

    # if not lang or not seed_page_title:
    #     print("Could not proceed due to URL parsing issues.")
    #     return

    # print(f"Processing seed page: '{seed_page_title}' on {lang}.wikipedia.org")

    wiki_instance = wikipediaapi.Wikipedia(language=lang, user_agent=ua.random)
    seed_page_object = wiki_instance.page(seed_page_title)

    # if not seed_page_object.exists():
    #     print(f"Seed page '{seed_page_title}' does not exist on {lang} Wikipedia.")
    #     return

    print(f"\n--- Links from '{seed_page_object.title}' ---")
    links = seed_page_object.links # dict: {'Linked Page Title': WikipediaPage object}

    if not links:
        print("No internal links found on the seed page.")
        return
    for key in links.keys():
        print(key)
    processed_count = 0
    for linked_page_title, linked_page_object in links.items():
        if processed_count >= max_links_to_process:
            print(f"\nReached limit of {max_links_to_process} linked pages to process.")
            break

        print(f"\n  🔗 Linked Page Title: {linked_page_title}")

        # The linked_page_object is already a WikipediaPage object.
        # Accessing its properties like .summary or .text might trigger an API call
        # by the library if the data hasn't been fetched yet.
        if linked_page_object.exists():
            # Use summary for brevity, or .text for more content
            summary = linked_page_object.summary
            print(f"     Summary (first {text_chars_limit} chars): {summary[:text_chars_limit]}...")
        else:
            print(f"     (Linked page '{linked_page_title}' does not exist or is a special page)")

        processed_count += 1
        time.sleep(1) # Be polite to the API, especially if processing many links

    print(f"\nFinished processing links from '{seed_page_object.title}'.")
    return links


print("-" * 40)

english_python_url = 'https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_Di_t%C3%ADch_qu%E1%BB%91c_gia_Vi%E1%BB%87t_Nam'
links = process_wikipedia_page_and_links(english_python_url, max_links_to_process=3)
# Out:
# ----------------------------------------
#
# --- Links from 'Danh sách Di tích quốc gia Việt Nam' ---
# ATK2
# ATK Chợ Đồn
# ATK Định Hóa
# Am Chúa
# An Biên (phường)
# An Bài, Quỳnh Phụ
# An Cựu
# Căn cứ Dốc Miếu - Cồn Tiên
# Căn cứ Minh Đạm
# Căn cứ Rừng Sác
# Căn cứ Tà Thiết
# Căn cứ Tân Sở
# Căn cứ Tỉnh ủy Cần Thơ
# Căn cứ Vũ Quang của khởi nghĩa Hương Khê
# Căng Bắc Mê
# Căng và đồn Nghĩa Lộ
# Cơ quan đặc ủy An Nam Cộng sản Đảng 1929-1930
# Cư M'gar
# Cảng quân sự Đông Hà
# Cần Giuộc
# Cần Đước
# Cầu Giấy
# Cầu Hiền Lương
# Cầu Ngang
# Cầu ngói chợ Lương
# Cầu treo Bến Tắt
# Cầu Đá Vũng Tàu
# Cẩm Giàng
# Cẩm Khê
# Cẩm Mỹ
# Cẩm Phả
# Cẩm Tây
# Cẩm Xuyên
# Cố đô Huế
# Cồn (thị trấn)
# Cồn Mô
# Cổ Lễ
# Cộng Hiền
# Cột cờ Hà Nội
# Cột cờ Lũng Cú
# Cột cờ Nam Định
# Cụm di tích Kha Sơn
# Cụm di tích phòng tuyến sông Như Nguyệt
# Cụm nhà cổ Thanh Phú Long
# Cứ điểm Làng Vây
# Cửa Lò
# Cửa biển Nhật Lệ
# Danh lam thắng cảnh Bàn Than – Hòn Mang – Hòn Dứa
# Danh sách di tích, di sản văn hóa ở Bắc Ninh
# Danh sách di tích tỉnh Thái Bình
# Danh sách đền tháp Chăm Pa
# Danh thắng Tây Thiên
# Di chỉ Gò Thành
# Di chỉ Nậm Tun
# Di chỉ Thạch Lạc
# Di chỉ khảo cổ Hòa Diêm
# Di chỉ khảo cổ Lung Leng
# Di chỉ Đồng Đậu
# Di sản thế giới
# Di tích Thảm sát Chợ Giữa
# Di tích Việt Nam
# Di tích Vàm Nhựt Tảo
# Di tích khảo cổ Cái Bèo
# Di tích khảo cổ Rạch Núi
# Di tích khảo cổ học Dốc Chùa
# Di tích khảo cổ núi Đầu Rằm
# Di tích quốc gia đặc biệt
# Di tích Óc Eo-Ba Thê
# Di tích ở Ninh Bình
# Dinh Cô
# Dinh Hoàng A Tưởng
# Dinh Thầy Thím
# Dinh thự họ Vương
# Dinh Độc Lập
# Diêm Điền, Thái Thụy
# Diên Khánh
# Diễn Châu
# Doãn Khuê
# Duy Nhất, Vũ Thư
# Duy Tiên
# Duy Xuyên
# Duyên Hải
# Duyên Hải (xã)
# Dĩ An
# Dũng Nghĩa, Vũ Thư
# Dương Hồng Thủy, Thái Thụy
# Dương Minh Châu
# Dầu Tiếng
# Dục Đức
# Ea Kar
# Ea Súp
# Ga Đà Lạt
# Gia Hội, Huế
# Gia Lâm
# Gia Lộc
# Gia Nghĩa
# Giao Thủy (thị trấn)
# Gio An
# Gio Linh (thị trấn)
# Gio Phong
# Giá Rai
# Giồng Cá Vồ
# Giồng Trôm
# Gò Công
# Gò Công Tây
# Gò Quao
# Gò Tháp
# Gò Đống Đa
# Gốm Chu Đậu-Mỹ Xá
# Hai Bà Trưng (quận)
# Hang Bua
# Hang Bói
# Hang Bụt
# Hang Chùa, Yên Thủy
# Hang Chổ
# Hang Con Moong
# Hang Cốc Mười
# Hang Dơi
# Hang Dơi Bắc Sơn
# Hang Gió (Chi Lăng)
# Hang Khâu Đôn
# Hang Khố Mỷ
# Hang Kéo Quảng
# Hang Luồn Chi Nê
# Hang Lạng Nắc
# Hang Muối
# Hang Mòi
# Hang Mường Tỉnh
# Hang Ngườm Bốc
# Hang Nà Chảo
# Hang Nà Luông
# Hang Nà Mò
# Hang Nậm Tan
# Hang Phia Muồn
# Hang Phia Vài
# Hang Phia Điểm
# Hang Phượng Hoàng - suối Mỏ Gà
# Hang Quàn
# Hang Rồng
# Hang Sa Khao
# Hang Thiên Thủy
# Hang Thẩm Khuyên
# Hang Trống
# Hang mộ Tạng Mè
# Hang xóm Trại và Mái đá làng Vành
# Hang Đá Đen
# Hang Đán Cúm
# Hang Đồng Thớt
# Hang đá Dak Tuar
# Hang Ốc
# Hiệp Hòa, Vũ Thư
# Hiệp Hòa (huyện)
# Hiệp Lực, Ngân Sơn
# Hoa Thám, Nguyên Bình
# Hoài Nhơn
# Hoài Ân
# Hoàng Công Chất
# Hoàng Hối Khanh
# Hoàng Mai (thị xã)
# Hoàng Ngũ Phúc
# Hoàng Phài
# Hoàng Su Phì
# Hoàng Tung, Hòa An
# Hoàng Văn Thụ
# Hoàng Văn Thụ, quận Hồng Bàng
# Hoàng thành Thăng Long
# Hoàng Đình Giong
# Hoành Bồ
# Huế
# Huỳnh Thúc Kháng
# Hà Giang (thành phố)
# Hà Quảng
# Hà Tiên
# Hà Trung
# Hà Tĩnh (thành phố)
# Hành cung Vũ Lâm
# Hòa An
# Hòa Bình (thành phố)
# Hòa Thành
# Hòa Tiến, Hưng Hà
# Hòa Tú 1, Mỹ Xuyên
# Hòn Chồng và Hòn Vợ
# Hòn Dáu
# Hòn Hai Cô Tiên
# Hòn Đất
# Hòn Đất (núi)
# Hòn Đỏ
# Hưng Nguyên
# Hưng Vũ, Bắc Sơn
# Hương Canh
# Hương Khê
# Hương Long, Huế
# Hương Sơn
# Hương Thủy
# Hạ Hòa
# Hạ Lang
# Hạ Long
# Hải An
# Hải An, Hải Lăng
# Hải Anh
# Hải Bắc
# Hải Dương (thành phố)
# Hải Hậu
# Hải Phú, Bố Trạch
# Hải Phúc
# Hải Tân, Hải Lăng
# Hậu Lộc
# Hệ thống công trình khai thác nước cổ Gio An
# Hệ thống giếng Chăm
# Hệ thống làng hầm Vĩnh Linh
# Hồ Ba Bể
# Hồ Chiềng Khoi
# Hồ Hoàn Kiếm
# Hồ Hưng Dật
# Hồ Lăk
# Hồ Nam (phường)
# Hồ T'Nưng
# Hồ Than Thở
# Hồ Thang Hen
# Hồ Thác Bà
# Hồ Tuyền Lâm
# Hồ Tùng Mậu
# Hồ Xuân Hương (Đà Lạt)
# Hồ Yên Lập
# Hồ Đạ Tẻh
# Hồng Anh Thư Quán
# Hồng Bàng (quận)
# Hồng Bạch, Đông Hưng
# Hồng Dân
# Hồng Dũng, Thái Thụy
# Hồng Lĩnh
# Hồng Minh, Hưng Hà
# Hồng Ngự
# Hồng Phong, An Dương
# Niết Bàn Tịnh Xá
# Noong Hẹt
# Nà Chì
# Nà Ngần
# Nà Quân
# Nàn Ma
# Núi Bà Rá
# Núi Bà Đen
# Núi Bài Thơ
# Núi Chung
# Núi Châu Thới
# Núi Chứa Chan
# Núi Cánh Diều
# Núi Hàm Rồng (Sa Pa)
# Núi Lam Thành
# Núi Langbiang
# Núi Mo So
# Núi Mằn
# Núi Non Nước
# Núi Quyết
# Núi Sam
# Núi Tà Cú
# Núi Tô Thị
# Núi Voi (Hải Phòng)
# Núi Đá Bia
# Núi Đá Dựng
# Núi Đôi Quản Bạ
# Núi đồn
# Nậm Lìn
# Phan Bội Châu
# Phan Ngọc Tòng
# Phan Rang – Tháp Chàm
# Phan Thanh Giản
# Phan Thiết
# Phan Văn Trị
# Phong Hiền
# Phong Thạnh A
# Phong Thạnh Tây
# Phong Thổ
# Phong trào Đồng khởi
# Phong Điền
# Phu Văn Lâu
# Phòng tuyến Tam Điệp
# Phù Cát
# Phù Ninh
# Phù Yên
# Phùng Chí Kiên
# Phú Bình
# Phú Hòa
# Phú Linh
# Phú Lương
# Phú Quốc
# Phú Riềng Đỏ
# Phú Thanh, Huế
# Phú Thiện
# Phú Thọ
# Phú Tân
# Phú Xuyên
# Phú Xuân, Bình Xuyên
# Phú Yên
# Phúc Thọ
# Phúc Yên
# Phương Định
# Phước Long
# Phước Đức Cổ Miếu (Miếu Ông Bổn)
# Phước Đức cổ miếu
# Phường 1, Ngã Năm
# Phường 3, thành phố Bạc Liêu
# Phường 3, thành phố Sóc Trăng
# Phường 5, thành phố Bạc Liêu
# Phường 6, thành phố Sóc Trăng
# Phường 8, thành phố Bạc Liêu
# Phường Lào Cai
# Phường Đúc
# Phượng Hoàng Trung Đô
# Phạm Huy Quang
# Phạm Nguyễn Du
# Phạm Thế Hiển
# Phạm Đôn Lễ
# Phố Hiến
# Phố Mới
# Phố cổ Đồng Văn
# Phổ Yên
# Phụng Hiệp
# Phủ Lý
# Phủ Tây Hồ
# Phủ Vườn Thiên
# Pleiku
# Quang Bình
# Quang Bình, Kiến Xương
# Quang Lịch, Kiến Xương
# Quang Minh, Kiến Xương
# Quang Trung, Kiến Xương
# Quy Nhơn
# Quách Đình Bảo
# Quản Bạ
# Quảng Lưu
# Quảng Ngãi (thành phố)
# Quảng Ninh
# Quảng Trạch
# Quảng Trị (thị xã)
# Quảng Yên
# Quảng trường Cách mạng tháng Tám
# Quần thể di sản thế giới Tràng An
# Quần thể di tích Hải Thượng Lãn Ông Lê Hữu Trác
# Quần thể di tích danh thắng Yên Tử
# Quần đảo Hòn Khoai
# Quận 1
# Quốc Oai
# Quốc Toản
# Quốc Tuấn, Nam Sách
# Quốc Tử Giám (Huế)
# Quỳ Châu
# Quỳnh Hoa, Quỳnh Phụ
# Quỳnh Hồng, Quỳnh Phụ
# Quỳnh Hội, Quỳnh Phụ
# Quỳnh Phụ
# Quỳnh Trang, Quỳnh Phụ
# Ruộng bậc thang Hoàng Su Phì
# Ruộng bậc thang Mù Cang Chải
# Rú Thành
# Tân Thành
# Tân Tiến, An Dương
# Tân Tiến, Hưng Hà
# Tân Trào, Kiến Thụy
# Tân Trụ
# Tân Uyên (thành phố)
# Tân Yên
# Tây Giang, Tiền Hải
# Tây Hồ (quận)
# Tây Sơn
# Tây Sơn, Kiến Xương
# Tây Sơn Tam Kiệt
# Tây Sơn Thượng đạo
# Tòa Thánh Tây Ninh
# Tùng Vài
# Tăng Bạt Hổ
# Tơ Tung
# Tư Nghĩa
# Tả Van Chư
# Tập đoàn cứ điểm Nà Sản
# Tịnh Biên
# Tịnh Khê
# Tịnh xá Ngọc Phương
# Tống Tất Thắng
# Tủa Chùa
# Từ Lương Xâm
# Từ Sơn
# Từ đường Phúc Quang
# Từ đường họ Mạc
# UNESCO
# U Minh
# U Minh Thượng
# Uông Bí
# Vinh
# Vinh Quang, Vĩnh Bảo
# Viện cơ mật (Huế)
# Việt Hùng, Vũ Thư
# Việt Thuận, Vũ Thư
# Việt Trì
# Việt Yên
# Vân Đồn
# Võ Di Nguy
# Võ Nhai
# Võ Trường Toản
# Võ Văn Dũng
# Văn Bàn
# Văn Chấn
# Văn Giang
# Văn Lâm
# Văn Miếu - Quốc Tử Giám
# Văn Miếu Diên Khánh
# Văn Miếu Huế
# Văn Miếu Mao Điền
# Văn Quán, Lập Thạch
# Văn Thánh Miếu Vĩnh Long
# Văn Tiến, Yên Lạc
# Văn Yên
# Văn hóa Sa Huỳnh
# Văn miếu Bắc Ninh
# Văn miếu Trấn Biên
# Văn miếu Xích Đằng
# Vĩnh Bảo
# Vĩnh Cửu
# Vĩnh Giang
# Vĩnh Hưng
# Vĩnh Hưng A
# Vĩnh Linh
# Vĩnh Long
# Vĩnh Lộc
# Vĩnh Lợi
# Vĩnh Sơn, Vĩnh Tường
# Vĩnh Thạch, Vĩnh Linh
# Vĩnh Yên
# Vũ Bình, Kiến Xương
# Vũ Quang
# Vũ Trung, Kiến Xương
# Vũ Văn Mật
# Vũng Tàu
# Vườn Di sản ASEAN
# Vườn quốc gia Cát Tiên
# Vườn quốc gia Cúc Phương
# Vườn quốc gia Phong Nha - Kẻ Bàng
# Vườn quốc gia U Minh Thượng
# Vạn Hương
# Vạn Ninh
# Vạn Thủy Tú
# Vị Thanh
# Vị Xuyên
# Vịnh Hạ Long
# Vịnh Vĩnh Hy
# Vịnh Xuân Đài
# Vụ thảm sát làng Tân Minh
# Wayback Machine
# Xa Dung
# Xuyên Mộc
# Xuân Hòa, Vũ Thư
# Xuân Lộc
# Xuân Thủy, Xuân Trường
# Xuân Đài
# Xá Nhè
# Xín Mần
# Xưởng đóng tàu Ba Son
# Y Miếu Thăng Long
# Yên Bái (thành phố)
# Yên Châu
# Yên Dũng
# Yên Lạc
# Yên Lạc (thị trấn)
# Yên Mỹ
# Yên Nghĩa, Ý Yên
# Yên Phú, Hàm Yên
# Yên Phụ, Yên Phong
# Yên Sơn
# Yên Sơn, Đô Lương
# Yên Thành
# Yên Thế
# Yên Thủy
# Yên Tiến, Ý Yên
# Yên Định
# Ái Tử
# Ông Ích Khiêm
# Ý Yên
# Đak Pơ
# Đakrông
# Đakrông (xã)
# Đan Phượng
# Đinh Bạt Tụy
# Đinh Văn Tả
# Điếm Trung Quân
# Điềm Mặc
# Điềm Mặc, Định Hóa
# Điền Môn
# Điểm cuối Đường ống xăng dầu VK96
# Điện Biên (huyện)
# Điện Biên Phủ
# Điện Biên Đông
# Điện Bàn
# Đoan Hùng
# Đoan Hùng, Hưng Hà
# Đoàn Quý phi
# Đà Bắc
# Đà Lạt
# Đà Nẵng
# Đài tưởng niệm Khâm Thiên
# Đào Trí
# Đào Tấn
# Đào Vũ Thường
# Đá Ba Chồng
# Đèo Gió (Xín Mần)
# Đèo Hải Vân
# Đèo Lũng Lô
# Đèo Mã Pí Lèng
# Đèo Ô Quý Hồ
# Đèo Đá Đẽo
# Đình, chùa Chi Lai
# Đình, chùa Do Nha
# Đình, chùa Đô Quan
# Đình An Quý
# Đình An Thái
# Đình An Trạch
# Đình An Vũ
# Đình Bàn Môn
# Đình Bình Hòa
# Đình Bình Thủy
# Đình Bích Chu
# Đình Bồ Bản
# Đình Cam Giá
# Đình Cao Quang
# Đình Chu
# Đình Chèm
# Đình Chí Hòa
# Đình Chí Linh
# Đình Chợ Xâm
# Đình Cổ Vũ
# Đình Dương Lôi
# Đình Dạ Lê
# Đình Dụ Nghĩa
# Đình Hoành Sơn
# Đình Hà Thượng
# Đình Hà Đậu
# Đình Hàng Kênh
# Đình Hòa Loan
# Đình Hùng Vĩ
# Đình Hưng Lộc
# Đình Hương Canh
# Đình Hương Câu
# Đình Hương Vĩ
# Đình Hải Châu
# Đình Khả Do
# Đình Kim Mã
# Đình Kim Ngân
# Đình Kim Sơn
# Đình Kiền Bái
# Đình Liễu Khê
# Đình Long Hưng
# Đình Long Thanh
# Đình Lạc Giao
# Đình Lễ Hợp
# Đình Minh Hương Gia Thạnh
# Đình Minh Lệ
# Đình Mão Điền Đoài
# Đình Nam Hương
# Đình Nam Đồng
# Đình Ngô Nội
# Đình Ngõa
# Đình Ngọc Canh
# Đình Ngọc Hà
# Đình Ngọc Khánh
# Đình Ngọc Xuyên
# Đình Nhu Thượng
# Đình Nại Nam
# Đình Phù Lưu
# Đình Phùng, Kiến Xương
# Đình Phú Cang
# Đình Phú Long
# Đình Phú Vinh (Vĩnh Phúc)
# Đình Phương Viên
# Đình Quan Lạn
# Đình Quy Lai
# Đình Quá Giáng
# Đình Quất Lưu
# Đình Quỳnh Hoàng
# Đình Ruồi
# Đình Sen Hồ (Vĩnh Phúc)
# Đình Sông Kênh
# Đình Sùng Văn
# Đình Thông Tây Hội
# Đình Thượng Đồng
# Đình Thạc Gián
# Đình Thạch Trục
# Đình Thổ Tang
# Đình Thủ Độ
# Đình Thứa Thượng
# Đình Tiên Hường
# Đình Tiên Lữ (Vĩnh Phúc)
# Đình Tiền hiền làng An Hải
# Đình Tri Chỉ
# Đình Tri Yếu
# Đình Trung Cần
# Đình Trà Cổ
# Đình Trâu Lỗ
# Đình Tuân Lộ
# Đình Tuý Loan
# Đình Tám Mái
# Đình Tân Hoa
# Đình Tân Hưng
# Đình Tây Hạ
# Đình Tấn Lộc
# Đình Tứ Đình
# Đình Văn Sơn
# Đình Vĩnh Khê
# Đình Vĩnh Ngươn
# Đình Vũ Thạch
# Đình Yên Lạc
# Đình Yên Nội (Vĩnh Phúc)
# Đình Yên Phụ
# Đình làng Chuông
# Đình làng Câu Nhi
# Đình làng Nghĩa An
# Đình làng Phú Đền
# Đình làng Quan Đình
# Đình và chùa Vĩnh Sơn
# Đình và đền Đông Hương
# Đình Đa Phước
# Đình Điều Hòa
# Đình Đình Bảng
# Đình Đình Chu
# Đình Đông Mai
# Đình Đông Đạo
# Đình Đại Phùng
# Đình Đại Yên
# Đình Đạm Xuyên
# Đình Đồng Dụ
# Đình Đồng Thạnh
# Đình Ứng Thiên
# Đô Lương
# Đô thị cổ Hội An
# Đông Anh
# Đông Ba, Huế
# Đông Cuông
# Đông Các, Đông Hưng
# Đông Dương, Đông Hưng
# Đông Hoà
# Đông Kinh, Đông Hưng
# Đông La, Đông Hưng
# Đông Lâm, Tiền Hải
# Đông Mỹ, thành phố Thái Bình
# Đông Phương, Đông Hưng
# Đông Quang, Đông Hưng
# Đông Sơn
# Đông Sơn, Thanh Hóa
# Đông Sơn, Đông Hưng
# Đông Triều
# Đông Tân, Đông Hưng
# Đông Xuân, Đông Hưng
# Đông Xá, Đông Hưng
# Đăk Glei
# Đăk Mil
# Đăk Song
# Đăk Tô
# Đường Châu Văn Liêm, Thành phố Hồ Chí Minh
# Đường Hồ Chí Minh trên biển
# Đường Trường Sơn
# Đạ Tẻh
# Đại Lộc
# Đại Từ
# Đại sứ quán Hoa Kỳ tại Sài Gòn
# Đạo Đức, Bình Xuyên
# Đảo Cò Chi Lăng Nam
# Đất Cuốc
# Đất Đỏ
# Đầm Dơi
# Đầm Ô Loan
# Đặng Cương
# Đặng Cương, An Dương
# Đặng Nguyên Cẩn
# Đặng Thúc Hứa
# Đề Thám
# Đền, chùa Hưng Thịnh
# Đền An Lư
# Đền Bà Chúa Kho (Bắc Ninh)
# Đền Bà Chúa Kho (Hà Nội)
# Đền Bà Chúa Kho (Hưng Yên)
# Đền Bà Kiệu
# Đền Bà Triệu
# Đền Bạch Mã
# Đền Bạch Mã (Thanh Chương)
# Đền Bắc Hà
# Đền Cao An Phụ
# Đền Cao Chí Linh
# Đền Chính Vị
# Đền Cuông
# Đền Cây Vải
# Đền Cô Chín
# Đền Cả Tổng Du Đồng
# Đền Cấm
# Đền Cầu Khoai
# Đền Cờn
# Đền Cửa Ông
# Đền Hai Bà Trưng
# Đền Hào Nam
# Đền Hùng
# Đền Hạ Tuyên Quang
# Đền Hồng Sơn
# Đền Kiếp Bạc
# Đền Kỳ Cùng
# Đền Liên Minh
# Đền Lý Bát Đế
# Đền Lý Quốc Sư
# Đền Mây
# Đền Mẫu (phường Quang Trung)
# Đền Mẫu Lào Cai
# Đền Mẫu Sinh
# Đền Mẫu Âu Cơ
# Đền Nam Hoà
# Đền Nghè
# Đền Ngô Miễn
# Đền Ngọc Lâm, Tân Mỹ
# Đền Ngọc Quế
# Đền Ngọc Sơn
# Đền Nhược Sơn
# Đền Núi
# Đền Nậm Sơn
# Đền Nội Bình Đà
# Đền Phù Đổng
# Đền Phù Ủng
# Đền Phú Xá
# Đền Phú Đa
# Đền Phượng Cương
# Đền Quan Đại
# Đền Quan Đế
# Đền Quán Thánh
# Đền Quảng Phúc
# Đền Quốc Phụ
# Đền Rặm
# Đền Sòng Sơn
# Đền Sóc
# Đền Sượt
# Đền Sọ
# Đền Thanh Liệt (Hưng Nguyên)
# Đền Thoại Ngọc Hầu
# Đền Thái Vi
# Đền Thái Yên
# Đền Thánh Mẫu (Vĩnh Phúc)
# Đền Thánh Nguyễn
# Đền Thính
# Đền Thõng
# Đền Thượng-Tây Thiên
# Đền Thượng Lào Cai
# Đền Thượng Tuyên Quang
# Đền Thần
# Đền Thọ Nam
# Đền Tiên Hạ
# Đền Tiên La
# Đền Tranh (Vĩnh Phúc)
# Đền Trinh Hưởng
# Đền Triệu Thái
# Đền Trung Đô
# Đền Tràng Kênh
# Đền Trâu Lỗ
# Đền Trìa
# Đền Trần (Nam Định)
# Đền Trần (Thái Bình)
# Đền Trần Hưng Đạo (Quảng Yên)
# Đền Voi Phục
# Đền Vua Lê (Nghệ An)
# Đền Vua Lê Đại Hành
# Đền Vua Đinh Tiên Hoàng
# Đền Vạn Lộc
# Đền Xuân Bảng
# Đền Xuân Hy
# Đền Xuân Lãng
# Đền Xuân Úc
# Đền chùa Xã Hạ
# Đền thờ Bác Hồ
# Đền thờ Chủ tịch Hồ Chí Minh (Bạc Liêu)
# Đền thờ Công chúa Phất Kim
# Đền thờ Hoàng Nghĩa Lương
# Đền thờ Khương Công Phụ
# Đền thờ Lê Đình Kiên
# Đền thờ Lý Thường Kiệt
# Đền thờ Nguyễn Chích
# Đền thờ Nguyễn Hữu Cảnh
# Đền thờ Nguyễn Xí
# Đền thờ Phương Giai
# Đền thờ Quản cơ Trần Văn Thành
# Đền thờ Trương Định
# Đền thờ Trần Hưng Đạo (Thanh Hóa)
# Đền thờ Trần Khát Chân
# Đền thờ Trần Quý Khoáng
# Đền thờ họ Mạc
# Đền thờ vua Lê Lợi
# Đền thờ và lăng mộ Lê Khôi
# Đền thờ và mộ Đức Thánh Hậu
# Đền thờ Đinh Bộ Lĩnh
# Đền vua Lê
# Đền Đinh Lễ
# Đền Đuông
# Đền Đô
# Đền Đông Cuông
# Đền Đông Hội
# Đền Đươi
# Đền Đống Nước
# Đền Đồng Bằng
# Đền Đồng Lạc
# Đền Đồng Nhân
# Đền Đồng Xuân (Quỳnh Lưu)
# Đền Đức Ông Trần Quốc Nghiễn
# Đệ tứ chiến khu Đông Triều
# Địa điểm Bác Hồ về thăm làng Cá Cát Bà
# Địa điểm Chiến thắng Xương Giang
# Địa điểm Cuộc nổi dậy của đồng bào Stiêng
# Địa điểm chiến thắng chốt chặn Tàu Ô
# Địa điểm chiến thắng đồi 722
# Địa điểm các đồn binh thời Trần
# Địa điểm căn cứ Cục hậu cần Quân giải phóng miền Nam Việt Nam (1973-1975)
# Địa điểm lưu niệm Chủ tịch Hồ Chí Minh ở Dương Nổ
# Địa điểm trận Giồng Bốm (1946)
# Địa đạo Bến Đình
# Địa đạo Củ Chi
# Địa đạo Hắc Dịch
# Địa đạo Kim Long
# Địa đạo Long Phước
# Địa đạo Phú Thọ Hòa
# Địa đạo Tây Nam Bến Cát
# Địa đạo Vĩnh Mốc
# Định Hóa
# Định Quán
# Định Trung
# Đống Đa
# Đồn Mộc Lỵ
# Đồn Phố Ràng
# Đồn cổ Đại Lịch
# Đồn điền Cada
# Đồng Cương
# Đồng Hới
# Đồng Hỷ
# Đồng Nọc Nạng
# Đồng Phú
# Đồng Tiến, Quỳnh Phụ
# Đồng Văn
# Đồng Văn, Yên Lạc
# Đồng Văn Cống
# Đồng Xoài
# Đồng Ích
# Đỗ Khắc Chung
# Đỗ Thúc Tịnh
# Đỗ Tử Bình
# Độc Lập, Hưng Hà
# Đội Việt Nam Tuyên truyền Giải phóng quân
# Động Am Tiên
# Động Bình Lư
# Động Hoa Lư
# Động Hoa Tiên
# Động Hàm Rồng
# Động Kính Chủ
# Động Linh Sơn
# Động Mường Vi
# Động Ngao
# Động Nhị Thanh
# Động Nàng Tiên
# Động Núi Niệm
# Động Pa Thơm
# Động Phong Nha
# Động Pu Sam Cáp
# Động Pê Răng Ky
# Động Song Long
# Động Thiên Hà
# Động Thiên Long Bắc Hà
# Động Thiên Long Yên Thủy
# Động Thiên Tôn
# Động Thác Bờ
# Động Tiên (Hàm Yên)
# Động Tiên Phi
# Động Tiên Sơn, Lai Châu
# Động Tả Phìn
# Động Xá Nhè
# Động Địch Lộng
# Đức Huệ
# Đức Hòa
# Đức Lý
# Đức Phổ
# Đức Thọ
# Đức Trọng
# Đức Xuân
# Ải Chi Lăng
# Ủy ban Liên hợp Đình chiến Nam Bộ
# Wikipedia:Liên kết hỏng
# Thể loại:Bài lỗi thời
#
#   🔗 Linked Page Title: ATK2
#      Summary (first 200 chars): ATK II (An toàn khu thứ hai) của Trung ương và Xứ ủy Bắc kỳ trong thời kỳ tiền khởi nghĩa là vùng đất gồm huyện Hiệp Hòa (Bắc Giang), huyện Phổ Yên và phần phía nam của huyện Phú Bình (Thái Nguyên). N...
#
#   🔗 Linked Page Title: ATK Chợ Đồn
#      (Linked page 'ATK Chợ Đồn' does not exist or is a special page)
#
#   🔗 Linked Page Title: ATK Định Hóa
#      Summary (first 200 chars): An toàn khu Định Hóa (ATK Định Hóa) là một khu di tích rộng lớn nằm ở tỉnh Thái Nguyên. Khu di tích này đã được công nhận là di tích quốc gia đặc biệt quan trọng của Việt Nam. Đây là nơi Chủ tịch Hồ C...
#
# Reached limit of 3 linked pages to process.
#
# Finished processing links from 'Danh sách Di tích quốc gia Việt Nam'.

# %%
links['Nhà số 7 phố Bến Ngự'].summary
# Out:
# ''

# %%
wiki_wiki.page('Nhà số 7 phố Bến Ngự')
# Out:
# Nhà số 7 phố Bến Ngự (lang: en, variant: None, id: ??, ns: 0)
