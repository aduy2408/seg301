# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
from selenium.common.exceptions import WebDriverException # To catch driver-level errors
from selenium.common.exceptions import WebDriverException, TimeoutException as SeleniumTimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException, StaleElementReferenceException
import time
import os
import re
from bs4 import BeautifulSoup, Tag, NavigableString
from fake_useragent import UserAgent
import pandas as pd 
from urllib.parse import urljoin, urlparse, parse_qs, urlencode

# %%
ua = UserAgent()

# %%
SUBJECTS_LIST =['https://www.cell.com/heliyon/ear-nose-throat',
 'https://www.cell.com/heliyon/earth-science',
 'https://www.cell.com/heliyon/economics',
 'https://www.cell.com/heliyon/education',
 'https://www.cell.com/heliyon/emergency-medicine',
 'https://www.cell.com/heliyon/endocrinology',
 'https://www.cell.com/heliyon/energy',
 'https://www.cell.com/heliyon/engineering',
 'https://www.cell.com/heliyon/environment',
 'https://www.cell.com/heliyon/evolution-ecology',
 'https://www.cell.com/heliyon/finance',
 'https://www.cell.com/heliyon/food-science-and-nutrition',
 'https://www.cell.com/heliyon/gastroenterology',
 'https://www.cell.com/heliyon/genetics',
 'https://www.cell.com/heliyon/haematology',
 'https://www.cell.com/heliyon/hepatology',
 'https://www.cell.com/heliyon/immunology',
 'https://www.cell.com/heliyon/infectious-diseases']
PAGE_SIZE = 100
BASE_URL = 'https://www.cell.com'

# %%
def initialize_uc_driver(headless=False, chrome_version_major=134, page_load_timeout_seconds=60): # Added timeout
    print("DEBUG: Initializing driver...")
    options = uc.ChromeOptions()
    if headless:
        options.add_argument('--headless')
        options.add_argument('--disable-gpu')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = uc.Chrome(options=options, version_main=chrome_version_major, use_subprocess=True)
    try:
        if driver: # Set timeout only if driver was initialized
            driver.set_page_load_timeout(page_load_timeout_seconds)
            print(f"DEBUG: Driver initialized. Page load timeout set to {page_load_timeout_seconds}s.")
    except Exception as e:
        print(f"CRITICAL: Driver initialization failed: {e}")
    return driver

# %%
def build_subject_page_url(base_subject_url, page_number, page_size):
    parsed_url = urlparse(base_subject_url)
    query_params = parse_qs(parsed_url.query)

        
    query_params['startPage'] = [str(page_number)]
    query_params['pageSize'] = [str(page_size)]

    # Rebuild url
    new_query_string = urlencode(query_params, doseq=True)
    return parsed_url._replace(query=new_query_string).geturl()

# %%
def get_article_hrefs_from_page(page_html_source):
    soup = BeautifulSoup(page_html_source, "lxml")
    main_content = soup.find(class_='rlist search-result__body items-results items-results--articles')
    href_list = []
    abs_href_for_append = None 

    title_h4_tags = main_content.find_all(class_='meta__title')

    for h4_tag in title_h4_tags:
        link_tag = h4_tag.find('a', class_='full-title-multi-search')
        if link_tag and link_tag.has_attr('href'):
            relative_href = link_tag.get('href')
            if relative_href:
                abs_href_for_append = urljoin(BASE_URL, relative_href)
                href_list.append(abs_href_for_append)
        #     else:
        #         print(f"    Found <a> tag with empty href: {h4_tag.get_text(strip=True)}")
        # else:
        #     print(f"    No valid <a> tag found in h4: {h4_tag.get_text(strip=True)}")
    return href_list

# %%
def get_total_pages(page_html_source):
    soup = BeautifulSoup(page_html_source, "lxml")
    pagination_info_tag = soup.find(class_='current-page') 
    if pagination_info_tag:
        text = pagination_info_tag.get_text(strip=True) 
        match = re.search(r'of\s*(\d+)', text, re.IGNORECASE)
        if match:
            try:
                total_pages = int(match.group(1))
                return total_pages
            except ValueError:
                print(f"    Warning: Could not parse total pages from text: '{text}'")

    else:
        print("    Warning: Pagination info tag (class 'current-page') not found. Assuming 1 page.")
        main_content_check = soup.find(class_='rlist search-result__body items-results items-results--articles')
        if main_content_check and main_content_check.find(class_='meta__title'):
             return 1
        else:
             return 0 

    return 1

# %%
driver = initialize_uc_driver(headless=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 driver = initialize_uc_driver(headless=False)
#
# Cell In[20], line 13, in initialize_uc_driver(chrome_version_major, headless)
#       8 options.add_argument("--disable-gpu")
#       9 options.add_argument("--start-maximized")
# ---> 13 driver = uc.Chrome(options=options, version_main=chrome_version_major)
#      14 return driver
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/undetected_chromedriver/__init__.py:258, in Chrome.__init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, desired_capabilities, advanced_elements, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, user_multi_procs, **kw)
#     251 self.patcher = Patcher(
#     252     executable_path=driver_executable_path,
#     253     force=patcher_force_close,
#     254     version_main=version_main,
#     255     user_multi_procs=user_multi_procs,
#     256 )
#     257 # self.patcher.auto(user_multiprocess = user_multi_num_procs)
# --> 258 self.patcher.auto()
#     260 # self.patcher = patcher
#     261 if not options:
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/undetected_chromedriver/patcher.py:178, in Patcher.auto(self, executable_path, force, version_main, _)
#     176 self.version_main = release.version[0]
#     177 self.version_full = release
# --> 178 self.unzip_package(self.fetch_package())
#     179 return self.patch()
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/undetected_chromedriver/patcher.py:287, in Patcher.fetch_package(self)
#     284     download_url %= (self.version_full.vstring, self.platform_name, zip_name)
#     286 logger.debug("downloading from %s" % download_url)
# --> 287 return urlretrieve(download_url)[0]
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/urllib/request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
all_collected_article_hrefs = {}
for subject_base_url in SUBJECTS_LIST[0:2]:
    subject_name = subject_base_url.split('/')[-1] 
    all_collected_article_hrefs[subject_name] = []
    current_subject_hrefs = []  
    page_zero_url = build_subject_page_url(subject_base_url, 0, PAGE_SIZE)
    print(f"  Navigating to initial page: {page_zero_url}")

    driver.get(page_zero_url)
    time.sleep(2) 
    page_html = driver.page_source

    hrefs_on_page_zero = get_article_hrefs_from_page(page_html)
    current_subject_hrefs.extend(hrefs_on_page_zero)
    print(f"    Scraped {len(hrefs_on_page_zero)} hrefs from page 0.")

    total_pages_for_subject = get_total_pages(page_html)
    print(f"    Detected {total_pages_for_subject} total pages for this subject.")


    for page_num in range(1, total_pages_for_subject):
        print(f"  Processing page {page_num + 1}/{total_pages_for_subject} (startPage={page_num})")
        next_page_url = build_subject_page_url(subject_base_url, page_num, PAGE_SIZE)
        print(f"    Navigating to: {next_page_url}")

        driver.get(next_page_url)
        time.sleep(2)

        page_html_next = driver.page_source

        hrefs_on_next_page = get_article_hrefs_from_page(page_html_next)
        current_subject_hrefs.extend(hrefs_on_next_page)
        print(f"      Scraped {len(hrefs_on_next_page)} hrefs.")
        time.sleep(1) # Politeness delay

    all_collected_article_hrefs[subject_name] = list(set(current_subject_hrefs)) # Store unique hrefs
    print(f"  Finished subject {subject_name}. Total unique hrefs collected: {len(all_collected_article_hrefs[subject_name])}")
# Out:
#   Navigating to initial page: https://www.cell.com/heliyon/ear-nose-throat?ContentItemType=fla&startPage=0&pageSize=100
#     Scraped 27 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject ear-nose-throat. Total unique hrefs collected: 27
#   Navigating to initial page: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 7 total pages for this subject.
#   Processing page 2/7 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/7 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/7 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/7 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/7 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/7 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/earth-science?ContentItemType=fla&startPage=6&pageSize=100
#       Scraped 18 hrefs.
#   Finished subject earth-science. Total unique hrefs collected: 618

# %%
all_collected_article_hrefs
# Out:
# {'ear-nose-throat': ['https://www.cell.com/heliyon/fulltext/S2405-8440(24)17424-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)10131-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10909-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01878-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02029-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01046-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05063-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00243-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06130-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00008-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14813-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11768-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05701-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00005-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03258-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)03315-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04927-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01782-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14743-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13615-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09807-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06491-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30718-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05560-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02277-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01836-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00478-9'],
#  'earth-science': ['https://www.cell.com/heliyon/fulltext/S2405-8440(24)10124-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05805-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35896-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06862-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)15191-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32714-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02601-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36590-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07350-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00985-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32435-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36578-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)37665-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09697-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00715-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05852-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05620-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05860-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05813-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05178-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02339-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01585-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06706-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31214-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06307-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04350-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)10457-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32218-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02199-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04737-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03908-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01267-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00975-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06865-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)03292-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09606-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01716-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32985-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00716-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00637-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)00239-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)37551-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07433-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36040-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00386-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11551-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07118-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(15)30389-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08750-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01207-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04804-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02057-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32209-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07733-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09726-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01273-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)31762-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00991-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36165-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16251-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02208-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)32444-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31935-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01688-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)32015-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02646-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35626-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00342-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)08843-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07774-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01252-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03241-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01547-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00868-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06065-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01446-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36455-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00064-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09554-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30165-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32688-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16892-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06919-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00419-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00991-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01120-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35780-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02687-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00853-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01083-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06805-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35977-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32032-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03023-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00963-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01783-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02972-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02787-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01102-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00494-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30752-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)04530-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00694-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02540-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08252-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36230-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01745-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00271-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)00241-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00873-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31020-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01824-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)08837-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31050-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16000-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02047-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36748-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00818-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03492-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32098-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00447-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00340-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01473-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06942-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00204-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31451-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06279-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04416-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01277-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00507-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)33460-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06736-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03517-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05775-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30332-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00583-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36301-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36142-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36357-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)03584-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)00440-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01767-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03096-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03249-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12242-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00955-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31327-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02615-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03164-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05190-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34857-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32912-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01782-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01293-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32459-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16862-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00512-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04825-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02044-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)31638-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03488-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11408-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02619-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34924-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07272-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32601-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05579-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03497-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30644-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00254-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02876-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00917-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06909-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06054-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)30732-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02366-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00230-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02953-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30429-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00128-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31769-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03253-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04827-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01981-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01866-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02214-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03321-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30137-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)37890-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)37122-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(15)30413-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14937-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02828-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02667-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02066-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36463-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14891-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36215-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36321-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01601-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01308-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01426-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36381-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08277-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36055-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00339-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)31188-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02752-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04824-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35862-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00855-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34551-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35808-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)32782-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14209-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03481-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02189-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(15)30316-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)30295-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)33292-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09838-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32504-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04805-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01590-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01144-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03752-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02324-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01354-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12637-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05151-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32550-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03081-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)30604-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04464-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03829-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(15)30400-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04955-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01592-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01859-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10455-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)32075-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02608-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00936-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07209-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)38835-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)08427-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)30263-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14573-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)32721-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07378-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36612-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)33442-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32398-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06767-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01625-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02440-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36274-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)31991-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03326-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01360-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02694-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31479-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03288-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00861-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00197-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07339-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30607-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01138-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32242-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02612-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01967-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00097-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02580-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01976-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01711-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00404-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32140-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35973-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00813-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34276-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31565-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36754-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14574-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04826-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01718-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01533-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02352-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)08037-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07003-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13947-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32457-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05148-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07435-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03549-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36613-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00994-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03064-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07555-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02571-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02482-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31849-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32741-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01268-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05499-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32814-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02783-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04411-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02811-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10257-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32460-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36292-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36263-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)35692-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03260-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05268-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32163-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08767-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13448-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00409-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00513-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14207-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00602-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07686-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02509-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03564-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02449-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36095-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36808-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34760-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14076-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16407-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00122-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00865-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)39028-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16254-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06238-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00923-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)33470-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32287-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31199-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00931-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)32093-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31671-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)31214-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34470-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01597-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11965-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32677-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)32596-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07060-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35766-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01600-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36734-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06142-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30172-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31349-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13249-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10078-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35930-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01978-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31797-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01000-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01517-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02066-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04828-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31934-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05583-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)17349-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)33282-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00889-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00205-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08999-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36494-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)10205-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03494-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)35698-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07240-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07567-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02004-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01720-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01993-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01723-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04571-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12208-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00341-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01543-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01302-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00974-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02499-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08323-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01776-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01180-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06747-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00672-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36038-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01493-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01083-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)32853-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01072-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07526-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30882-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01743-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)32037-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01705-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00585-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)32084-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05851-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02084-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09287-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34957-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36822-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02233-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)30858-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34913-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01696-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30481-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01563-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04412-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11305-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00495-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36769-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11982-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06602-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09321-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01897-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)30934-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06138-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35759-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)32360-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35949-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)17224-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02350-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04465-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32469-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07257-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01693-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04575-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35921-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01145-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05111-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05367-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31658-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)16041-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31715-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01087-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00867-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)03165-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05619-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02779-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00986-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)08870-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00086-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01435-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06456-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03696-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00071-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01726-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06057-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01228-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00539-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06756-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00765-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31093-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01183-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32818-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12831-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36129-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)14377-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)31312-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02623-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30092-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07450-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00400-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00627-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01067-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02435-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02684-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05558-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07528-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07237-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35920-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36223-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04812-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)37335-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01861-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06328-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36762-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36317-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)30269-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07185-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03492-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36793-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01856-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36123-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02956-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)02675-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00625-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00533-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04620-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01078-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00264-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01665-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)33365-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01223-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31340-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)02053-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31863-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)30976-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12381-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36261-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00862-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)32772-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01030-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01049-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12163-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)04885-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00529-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)07012-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01178-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10542-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02617-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30384-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01846-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)04759-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30803-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36255-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31881-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00953-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)00836-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04576-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01542-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)31540-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03486-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32444-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09119-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01882-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13383-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01956-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09910-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01471-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35743-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)08380-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)00477-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03181-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01653-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02573-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03724-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32108-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34355-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00520-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03235-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01488-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)09121-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01146-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)32111-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01938-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00305-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)04621-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00505-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)35019-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36122-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)38158-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01699-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34807-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)36167-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(16)30386-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)34232-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10272-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31981-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00297-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35596-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00890-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02213-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00946-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00380-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)32334-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30396-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)07422-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)01983-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09700-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35802-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(19)35567-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)01204-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)06863-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05856-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)00853-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)01085-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03236-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)31029-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)31393-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02596-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01358-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)00394-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)01164-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03240-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00246-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12437-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)12018-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(22)02677-9',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)00251-6',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)09074-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30826-4',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)05585-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)10826-7',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00691-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01687-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(18)36662-3',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)03263-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)00343-8',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)11635-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(23)05675-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(25)01140-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(17)31731-0',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(21)02498-1',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)13479-2',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(20)30506-5',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(24)06393-X',
#   'https://www.cell.com/heliyon/fulltext/S2405-8440(15)30144-4']}

# %%
def run_pipeline():
    driver = initialize_uc_driver(headless=False)


    all_collected_article_hrefs = {}
    for subject_base_url in SUBJECTS_LIST:
        subject_name = subject_base_url.split('/')[-1] 
        all_collected_article_hrefs[subject_name] = []
        current_subject_hrefs = []  
        page_zero_url = build_subject_page_url(subject_base_url, 0, PAGE_SIZE)
        print(f"  Navigating to initial page: {page_zero_url}")

        driver.get(page_zero_url)
        time.sleep(2) 
        page_html = driver.page_source

        hrefs_on_page_zero = get_article_hrefs_from_page(page_html)
        current_subject_hrefs.extend(hrefs_on_page_zero)
        print(f"    Scraped {len(hrefs_on_page_zero)} hrefs from page 0.")

        total_pages_for_subject = get_total_pages(page_html)
        print(f"    Detected {total_pages_for_subject} total pages for this subject.")


        for page_num in range(1, total_pages_for_subject):
            print(f"  Processing page {page_num + 1}/{total_pages_for_subject} (startPage={page_num})")
            next_page_url = build_subject_page_url(subject_base_url, page_num, PAGE_SIZE)
            print(f"    Navigating to: {next_page_url}")

            driver.get(next_page_url)
            time.sleep(2)

            page_html_next = driver.page_source

            hrefs_on_next_page = get_article_hrefs_from_page(page_html_next)
            current_subject_hrefs.extend(hrefs_on_next_page)
            print(f"      Scraped {len(hrefs_on_next_page)} hrefs.")
            time.sleep(1) 

        all_collected_article_hrefs[subject_name] = list(set(current_subject_hrefs)) # Store unique hrefs
        print(f"  Finished subject {subject_name}. Total unique hrefs collected: {len(all_collected_article_hrefs[subject_name])}")

    driver.quit()
    print("\nWebDriver closed.")

    return all_collected_article_hrefs

if __name__ == '__main__':
    ariticle_links = run_pipeline()
# Out:
#   Navigating to initial page: https://www.cell.com/heliyon/ear-nose-throat?startPage=0&pageSize=100
#     Scraped 34 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject ear-nose-throat. Total unique hrefs collected: 34
#   Navigating to initial page: https://www.cell.com/heliyon/earth-science?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 7 total pages for this subject.
#   Processing page 2/7 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/7 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/7 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/7 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/7 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/7 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/earth-science?startPage=6&pageSize=100
#       Scraped 56 hrefs.
#   Finished subject earth-science. Total unique hrefs collected: 656
#   Navigating to initial page: https://www.cell.com/heliyon/economics?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 7 total pages for this subject.
#   Processing page 2/7 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/7 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/7 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/7 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/7 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/7 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/economics?startPage=6&pageSize=100
#       Scraped 99 hrefs.
#   Finished subject economics. Total unique hrefs collected: 699
#   Navigating to initial page: https://www.cell.com/heliyon/education?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 12 total pages for this subject.
#   Processing page 2/12 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/12 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/12 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/12 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/12 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/12 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=6&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 8/12 (startPage=7)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=7&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 9/12 (startPage=8)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=8&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 10/12 (startPage=9)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=9&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 11/12 (startPage=10)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=10&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 12/12 (startPage=11)
#     Navigating to: https://www.cell.com/heliyon/education?startPage=11&pageSize=100
#       Scraped 24 hrefs.
#   Finished subject education. Total unique hrefs collected: 1124
#   Navigating to initial page: https://www.cell.com/heliyon/emergency-medicine?startPage=0&pageSize=100
#     Scraped 66 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject emergency-medicine. Total unique hrefs collected: 66
#   Navigating to initial page: https://www.cell.com/heliyon/endocrinology?startPage=0&pageSize=100
#     Scraped 58 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject endocrinology. Total unique hrefs collected: 58
#   Navigating to initial page: https://www.cell.com/heliyon/energy?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 12 total pages for this subject.
#   Processing page 2/12 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/12 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/12 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/12 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/12 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/12 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=6&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 8/12 (startPage=7)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=7&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 9/12 (startPage=8)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=8&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 10/12 (startPage=9)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=9&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 11/12 (startPage=10)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=10&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 12/12 (startPage=11)
#     Navigating to: https://www.cell.com/heliyon/energy?startPage=11&pageSize=100
#       Scraped 21 hrefs.
#   Finished subject energy. Total unique hrefs collected: 1121
#   Navigating to initial page: https://www.cell.com/heliyon/engineering?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 33 total pages for this subject.
#   Processing page 2/33 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/33 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/33 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/33 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/33 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/33 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=6&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 8/33 (startPage=7)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=7&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 9/33 (startPage=8)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=8&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 10/33 (startPage=9)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=9&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 11/33 (startPage=10)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=10&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 12/33 (startPage=11)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=11&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 13/33 (startPage=12)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=12&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 14/33 (startPage=13)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=13&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 15/33 (startPage=14)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=14&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 16/33 (startPage=15)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=15&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 17/33 (startPage=16)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=16&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 18/33 (startPage=17)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=17&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 19/33 (startPage=18)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=18&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 20/33 (startPage=19)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=19&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 21/33 (startPage=20)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=20&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 22/33 (startPage=21)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=21&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 23/33 (startPage=22)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=22&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 24/33 (startPage=23)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=23&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 25/33 (startPage=24)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=24&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 26/33 (startPage=25)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=25&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 27/33 (startPage=26)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=26&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 28/33 (startPage=27)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=27&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 29/33 (startPage=28)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=28&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 30/33 (startPage=29)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=29&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 31/33 (startPage=30)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=30&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 32/33 (startPage=31)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=31&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 33/33 (startPage=32)
#     Navigating to: https://www.cell.com/heliyon/engineering?startPage=32&pageSize=100
#       Scraped 100 hrefs.
#   Finished subject engineering. Total unique hrefs collected: 2100
#   Navigating to initial page: https://www.cell.com/heliyon/environment?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 28 total pages for this subject.
#   Processing page 2/28 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/28 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/28 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/28 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/28 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/28 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=6&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 8/28 (startPage=7)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=7&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 9/28 (startPage=8)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=8&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 10/28 (startPage=9)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=9&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 11/28 (startPage=10)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=10&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 12/28 (startPage=11)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=11&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 13/28 (startPage=12)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=12&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 14/28 (startPage=13)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=13&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 15/28 (startPage=14)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=14&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 16/28 (startPage=15)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=15&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 17/28 (startPage=16)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=16&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 18/28 (startPage=17)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=17&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 19/28 (startPage=18)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=18&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 20/28 (startPage=19)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=19&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 21/28 (startPage=20)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=20&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 22/28 (startPage=21)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=21&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 23/28 (startPage=22)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=22&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 24/28 (startPage=23)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=23&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 25/28 (startPage=24)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=24&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 26/28 (startPage=25)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=25&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 27/28 (startPage=26)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=26&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 28/28 (startPage=27)
#     Navigating to: https://www.cell.com/heliyon/environment?startPage=27&pageSize=100
#       Scraped 100 hrefs.
#   Finished subject environment. Total unique hrefs collected: 2100
#   Navigating to initial page: https://www.cell.com/heliyon/evolution-ecology?startPage=0&pageSize=100
#     Scraped 40 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject evolution-ecology. Total unique hrefs collected: 40
#   Navigating to initial page: https://www.cell.com/heliyon/finance?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 5 total pages for this subject.
#   Processing page 2/5 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/finance?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/5 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/finance?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/5 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/finance?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/5 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/finance?startPage=4&pageSize=100
#       Scraped 15 hrefs.
#   Finished subject finance. Total unique hrefs collected: 415
#   Navigating to initial page: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 20 total pages for this subject.
#   Processing page 2/20 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/20 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/20 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/20 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/20 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/20 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=6&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 8/20 (startPage=7)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=7&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 9/20 (startPage=8)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=8&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 10/20 (startPage=9)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=9&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 11/20 (startPage=10)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=10&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 12/20 (startPage=11)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=11&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 13/20 (startPage=12)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=12&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 14/20 (startPage=13)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=13&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 15/20 (startPage=14)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=14&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 16/20 (startPage=15)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=15&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 17/20 (startPage=16)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=16&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 18/20 (startPage=17)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=17&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 19/20 (startPage=18)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=18&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 20/20 (startPage=19)
#     Navigating to: https://www.cell.com/heliyon/food-science-and-nutrition?startPage=19&pageSize=100
#       Scraped 18 hrefs.
#   Finished subject food-science-and-nutrition. Total unique hrefs collected: 1918
#   Navigating to initial page: https://www.cell.com/heliyon/gastroenterology?startPage=0&pageSize=100
#     Scraped 44 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject gastroenterology. Total unique hrefs collected: 44
#   Navigating to initial page: https://www.cell.com/heliyon/genetics?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 5 total pages for this subject.
#   Processing page 2/5 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/genetics?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/5 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/genetics?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/5 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/genetics?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/5 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/genetics?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Finished subject genetics. Total unique hrefs collected: 500
#   Navigating to initial page: https://www.cell.com/heliyon/haematology?startPage=0&pageSize=100
#     Scraped 26 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject haematology. Total unique hrefs collected: 26
#   Navigating to initial page: https://www.cell.com/heliyon/hepatology?startPage=0&pageSize=100
#     Scraped 34 hrefs from page 0.
#     Detected 1 total pages for this subject.
#   Finished subject hepatology. Total unique hrefs collected: 34
#   Navigating to initial page: https://www.cell.com/heliyon/immunology?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 7 total pages for this subject.
#   Processing page 2/7 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/7 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/7 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/7 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/7 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/7 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/immunology?startPage=6&pageSize=100
#       Scraped 71 hrefs.
#   Finished subject immunology. Total unique hrefs collected: 671
#   Navigating to initial page: https://www.cell.com/heliyon/infectious-diseases?startPage=0&pageSize=100
#     Scraped 100 hrefs from page 0.
#     Detected 7 total pages for this subject.
#   Processing page 2/7 (startPage=1)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=1&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 3/7 (startPage=2)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=2&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 4/7 (startPage=3)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=3&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 5/7 (startPage=4)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=4&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 6/7 (startPage=5)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=5&pageSize=100
#       Scraped 100 hrefs.
#   Processing page 7/7 (startPage=6)
#     Navigating to: https://www.cell.com/heliyon/infectious-diseases?startPage=6&pageSize=100
#       Scraped 6 hrefs.
#   Finished subject infectious-diseases. Total unique hrefs collected: 606
#
# WebDriver closed.

# %%
import json
output_file = "heliyon.json"

try:
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(ariticle_links, f, ensure_ascii=False, indent=4)
    print(f"Dictionary saved to '{output_file}'")
except IOError as e:
    print(f"Error saving dictionary to JSON file: {e}")
# Out:
# Dictionary saved to 'heliyon.json'

# %% [markdown]
# # Main subjects scraper

# %%
driver = uc.Chrome()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 driver = uc.Chrome()
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/undetected_chromedriver/__init__.py:466, in Chrome.__init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, desired_capabilities, advanced_elements, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, user_multi_procs, **kw)
#     459     self.browser_pid = browser.pid
#     462 service = selenium.webdriver.chromium.service.ChromiumService(
#     463     self.patcher.executable_path
#     464 )
# --> 466 super(Chrome, self).__init__(
#     467     service=service,
#     468     options=options,
#     469     keep_alive=keep_alive,
#     470 )
#     472 self.reactor = None
#     474 if enable_cdp_events:
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/chromium/webdriver.py:66, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      57 executor = ChromiumRemoteConnection(
#      58     remote_server_addr=self.service.service_url,
#      59     browser_name=browser_name,
#    (...)
#      62     ignore_proxy=options._ignore_local_proxy,
#      63 )
#      65 try:
# ---> 66     super().__init__(command_executor=executor, options=options)
#      67 except Exception:
#      68     self.quit()
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:250, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     248 self._authenticator_id = None
#     249 self.start_client()
# --> 250 self.start_session(capabilities)
#     251 self._fedcm = FedCM(self)
#     253 self._websocket_connection = None
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/undetected_chromedriver/__init__.py:724, in Chrome.start_session(self, capabilities, browser_profile)
#     722 if not capabilities:
#     723     capabilities = self.options.to_capabilities()
# --> 724 super(selenium.webdriver.chrome.webdriver.WebDriver, self).start_session(
#     725     capabilities
#     726 )
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:342, in WebDriver.start_session(self, capabilities)
#     333 """Creates a new session with the desired capabilities.
#     334
#     335 Parameters:
#    (...)
#     338     - A capabilities dict to start the session with.
#     339 """
#     341 caps = _create_caps(capabilities)
# --> 342 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     343 self.session_id = response.get("sessionId")
#     344 self.caps = response.get("capabilities")
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: cannot connect to chrome at 127.0.0.1:33461
# from session not created: This version of ChromeDriver only supports Chrome version 136
# Current browser version is 134.0.6998.165
# Stacktrace:
# #0 0x5ae93134471a <unknown>
# #1 0x5ae930de70a0 <unknown>
# #2 0x5ae930e27a47 <unknown>
# #3 0x5ae930e26935 <unknown>
# #4 0x5ae930e1c373 <unknown>
# #5 0x5ae930e6cd75 <unknown>
# #6 0x5ae930e6c296 <unknown>
# #7 0x5ae930e5e173 <unknown>
# #8 0x5ae930e2ad4b <unknown>
# #9 0x5ae930e2b9b1 <unknown>
# #10 0x5ae9313098cb <unknown>
# #11 0x5ae93130d7ca <unknown>
# #12 0x5ae9312f1622 <unknown>
# #13 0x5ae93130e354 <unknown>
# #14 0x5ae9312d645f <unknown>
# #15 0x5ae9313324f8 <unknown>
# #16 0x5ae9313326d6 <unknown>
# #17 0x5ae931343586 <unknown>
# #18 0x7714cff6a7eb <unknown>
# #19 0x7714cffee18c <unknown>

# %%
page_html_2 = driver.page_source

# %%
soup = BeautifulSoup(page_html_2, "lxml")

# %%
subjects = soup.find(class_='subjList col4')

# %%
subjects_li = subjects.find_all("li")

# %%
len(subjects_li)
# Out:
# 71

# %%
subjects_li
# Out:
# [<li><a href="/heliyon/agriculture">Agriculture</a></li>,
#  <li><a href="/heliyon/animal-science">Animal Science</a></li>,
#  <li><a href="/heliyon/applied-psychology">Applied Psychology</a></li>,
#  <li><a href="/heliyon/biochem-mol-cell-bio">Biochemistry, Molecular and Cell Biology</a></li>,
#  <li><a href="/heliyon/bioinformatics-computational-biology">Bioinformatics and Computational Biology</a></li>,
#  <li><a href="/heliyon/business-management">Business and Management</a></li>,
#  <li><a href="/heliyon/cancer-research">Cancer Research</a></li>,
#  <li><a href="/heliyon/cardiology-cardiovascular-medicine">Cardiology and Cardiovascular Medicine</a></li>,
#  <li><a href="/heliyon/chemical-engineering">Chemical Engineering</a></li>,
#  <li><a href="/heliyon/chemistry">Chemistry</a></li>,
#  <li><a href="/heliyon/civil-engineering">Civil Engineering</a></li>,
#  <li><a href="/heliyon/clinical-psychology-psychiatry">Clinical Psychology and Psychiatry</a></li>,
#  <li><a href="/heliyon/clinical-research">Clinical Research</a></li>,
#  <li><a href="/heliyon/computer-science">Computer Science</a></li>,
#  <li><a href="/heliyon/dentistry">Dentistry</a></li>,
#  <li><a href="/heliyon/dermatology">Dermatology</a></li>,
#  <li><a href="/heliyon/developmental-stem-cell-biology">Development and Stem Cell Biology</a></li>,
#  <li><a href="/heliyon/ear-nose-throat">Ear, Nose, Throat</a></li>,
#  <li><a href="/heliyon/earth-science">Earth Science</a></li>,
#  <li><a href="/heliyon/economics">Economics</a></li>,
#  <li><a href="/heliyon/education">Education</a></li>,
#  <li><a href="/heliyon/emergency-medicine">Emergency Medicine</a></li>,
#  <li><a href="/heliyon/endocrinology">Endocrinology</a></li>,
#  <li><a href="/heliyon/energy">Energy</a></li>,
#  <li><a href="/heliyon/engineering">Engineering</a></li>,
#  <li><a href="/heliyon/environment">Environment</a></li>,
#  <li><a href="/heliyon/evolution-ecology">Evolution and Ecology</a></li>,
#  <li><a href="/heliyon/finance">Finance</a></li>,
#  <li><a href="/heliyon/food-science-and-nutrition">Food Science and Nutrition</a></li>,
#  <li><a href="/heliyon/gastroenterology">Gastroenterology</a></li>,
#  <li><a href="/heliyon/genetics">Genetics</a></li>,
#  <li><a href="/heliyon/haematology">Haematology</a></li>,
#  <li><a href="/heliyon/hepatology">Hepatology</a></li>,
#  <li><a href="/heliyon/immunology">Immunology</a></li>,
#  <li><a href="/heliyon/infectious-diseases">Infectious Diseases</a></li>,
#  <li><a href="/heliyon/information-science">Information Science</a></li>,
#  <li><a href="/heliyon/intensive-care-medicine">Intensive Care Medicine</a></li>,
#  <li><a href="/heliyon/marine-biology">Marine Biology</a></li>,
#  <li><a href="/heliyon/materials-science">Materials Science</a></li>,
#  <li><a href="/heliyon/mathematics">Mathematics</a></li>,
#  <li><a href="/heliyon/mechanical-engineering">Mechanical Engineering</a></li>,
#  <li><a href="/heliyon/medical-imaging">Medical Imaging</a></li>,
#  <li><a href="/heliyon/microbiology">Microbiology</a></li>,
#  <li><a href="/heliyon/nephrology">Nephrology</a></li>,
#  <li><a href="/heliyon/neurology">Neurology</a></li>,
#  <li><a href="/heliyon/neuroscience">Neuroscience</a></li>,
#  <li><a href="/heliyon/nursing-health-professions">Nursing and Health Professions</a></li>,
#  <li><a href="/heliyon/oncology">Oncology</a></li>,
#  <li><a href="/heliyon/ophthalmology">Ophthalmology</a></li>,
#  <li><a href="/heliyon/paediatrics">Paediatrics</a></li>,
#  <li><a href="/heliyon/pathology-laboratory-medicine">Pathology and Laboratory Medicine</a></li>,
#  <li><a href="/heliyon/pharmaceutical-science">Pharmaceutical Science</a></li>,
#  <li><a href="/heliyon/pharmacology-toxicology">Pharmacology and Toxicology</a></li>,
#  <li><a href="/heliyon/physics">Physics</a></li>,
#  <li><a href="/heliyon/plant-biology">Plant Biology</a></li>,
#  <li><a href="/heliyon/public-health">Public Health</a></li>,
#  <li><a href="/heliyon/respiratory-medicine">Respiratory Medicine</a></li>,
#  <li><a href="/heliyon/rheumatology">Rheumatology</a></li>,
#  <li><a href="/heliyon/rural-development">Rural Development</a></li>,
#  <li><a href="/heliyon/sleep-medicine">Sleep Medicine</a></li>,
#  <li><a href="/heliyon/society-politics">Society and Politics</a></li>,
#  <li><a href="/heliyon/soil-science">Soil Science</a></li>,
#  <li><a href="/heliyon/sport-exercise-medicine">Sport and Exercise Medicine</a></li>,
#  <li><a href="/heliyon/surgery">Surgery</a></li>,
#  <li><a href="/heliyon/tourism-hospitality">Tourism and Hospitality</a></li>,
#  <li><a href="/heliyon/urban-development">Urban Development</a></li>,
#  <li><a href="/heliyon/urology">Urology</a></li>,
#  <li><a href="/heliyon/veterinary-science">Veterinary Science</a></li>,
#  <li><a href="/heliyon/virology">Virology</a></li>,
#  <li><a href="/heliyon/womens-health">Women's Health</a></li>,
#  <li><a href="/heliyon/zoology">Zoology</a></li>]

# %%
main_subjects_links = []
base_url = 'https://www.cell.com/'
for subject in subjects_li:
    link_subject = subject.find('a')
    if link_subject and link_subject.has_attr('href'):
        relative_href = link_subject['href'] 
        
        abs_href = urljoin(base_url,relative_href)
    
    main_subjects_links.append(abs_href)

# %%
my_subjects_links = main_subjects_links[17:35]
# Out:
# ['https://www.cell.com/heliyon/ear-nose-throat',
#  'https://www.cell.com/heliyon/earth-science',
#  'https://www.cell.com/heliyon/economics',
#  'https://www.cell.com/heliyon/education',
#  'https://www.cell.com/heliyon/emergency-medicine',
#  'https://www.cell.com/heliyon/endocrinology',
#  'https://www.cell.com/heliyon/energy',
#  'https://www.cell.com/heliyon/engineering',
#  'https://www.cell.com/heliyon/environment',
#  'https://www.cell.com/heliyon/evolution-ecology',
#  'https://www.cell.com/heliyon/finance',
#  'https://www.cell.com/heliyon/food-science-and-nutrition',
#  'https://www.cell.com/heliyon/gastroenterology',
#  'https://www.cell.com/heliyon/genetics',
#  'https://www.cell.com/heliyon/haematology',
#  'https://www.cell.com/heliyon/hepatology',
#  'https://www.cell.com/heliyon/immunology',
#  'https://www.cell.com/heliyon/infectious-diseases']

# %% [markdown]
# ## Single article scrape abstract + kwords

# %%
driver =  initialize_uc_driver(headless=False)

# %%
driver.get('https://www.cell.com/heliyon/fulltext/S2405-8440(22)02029-1')

# %%
page_html = driver.page_source

# %%
soup = BeautifulSoup(page_html, 'lxml')

# %%
abstract = soup.find(id='abspara0010')

# %%
abstract.text
# Out:
# 'Granulomatous formation in the nose and paranasal sinuses still presents an unmet clinical challenge as it affects both the physical health and personality of patients, and the lack of a systematic diagnostic and disease management approach has further complicated the scenario. Occurrence of granulomatous nasal disorder in the rural Indian population is associated with several factors such as lack of proper medical care, lack of hygienic and clean working and living conditions, and limited financial abilities to access the already overburdened primary healthcare system. This study aims to understand the correlation disease incidence, manifestation of signs and symptoms and associated socio-epidemiological parameters for 104,000 patients over a period of 23 months in Odisha. Primarily the study used socio-epidemiological surveys collected, annotated, and curated independently for granulomatous nasal disorder patients and compared this with their clinical records for signs & symptoms and performed several statistical analyses to better understand the disease incidence correlation with age, socio-economic and gender based parameters. Overall results suggest that males from low socio-economic background living in rural areas are the most vulnerable population and commonly affected with granulomatous nasal disorder (commonly Rhinosporidiosis sub-type) with common origin of the disease reported at the nasal septum and floor. We also highlight that change in the mass of nose followed by bleeds on touch, nasal discharge and hanging mass in throat are the most common manifestations presented by patients with granulomatous nasal disorders. Together, this research work identifies and characterise clinical and socio-economic factors that lead to and exacerbate the incidence of granulomatous nasal disorders.'

# %%
kw = soup.find(id = 'keywords')

# %%
li_kw = kw.find_all('li')

# %%
for tag in li_kw:
    print(tag.text)
# Out:
# Granulomatous
# Nose
# Paranasal sinuses
# Males
# Rural area
# Poor living condition
# Rhinosporidiosis
# Fungal granuloma
# Rhinoscleroma
# Tuberculosis
# Leprosy

# %%
# --- Function to Scrape Article Details ---
def scrape_article_details_with_uc_and_bs4(article_url):

    print(f"  Navigating to article: {article_url}")
    article_data = {
        "url": article_url,
        "title": "N/A",
        "abstract": "N/A",
        "keywords": [] 
    }

    try:
        driver.get(article_url)
        page_html = driver.page_source
        # time.sleep(1) 
        soup = BeautifulSoup(page_html, 'lxml') 

        # Title 
        title_tag = soup.find('h1',  attrs={'property': 'name'})
        if not title_tag:
            print('FUCK THERE IS NO TITLE')
        article_data['title'] = title_tag.text.strip()

        # Abstract 
        abstract_text = "N/A"
        abstract_element = soup.find(id='abspara0010')
        if not abstract_element or 'withdrawn' in abstract_element.text:
            print("NO ABSTRACT, HELP!!!!@@@!!")
        else:
            abstract_text = abstract_element.get_text(strip=True)
        article_data['abstract'] = abstract_text if abstract_text else "N/A"


        # Keywords 
        keywords_list = []
        keywords_section = soup.find(id='keywords')
        if not keywords_section:
            keywords_section = soup.find(id ='index terms')
        if keywords_section:
            li_items = keywords_section.find_all('li')
            if li_items:
                for li in li_items:
                    kw_text = li.get_text(strip=True)
                    if kw_text:
                        keywords_list.append(kw_text)



        article_data['keywords'] = keywords_list if keywords_list else []

        print(f"    Title: {article_data['title'][:60]}...")
        print(f"    Abstract found: {True if article_data['abstract'] not in ['N/A', ''] else False} (Length: {len(article_data['abstract'])})")
        print(f"    Keywords found: {True if article_data['keywords'] else False} (Count: {len(article_data['keywords'])}) -> {article_data['keywords'][:5]}")



    except SeleniumTimeoutException:
        print(f"  !!! SeleniumTimeoutException (Page Load Timeout) for {article_url}")
        article_data['title'] = "ERROR_PAGE_LOAD_TIMEOUT"
    except WebDriverException as e:
        print(f"  !!! WebDriverException for {article_url}: {e}")
        article_data['title'] = f"ERROR_WEBDRIVER_EXCEPTION: {type(e).__name__}"
    except Exception as e: 
        print(f"  An error occurred while processing {article_url} (parsing): {e}")
        if not article_data['title'].startswith("ERROR"):
            article_data['title'] = f"ERROR_PARSING: {type(e).__name__}"
    return article_data

# %%
driver = initialize_uc_driver(headless=False)

# %%
flat_url_list = []
for subject, urls in data_dict.items():
    for url in urls:
        flat_url_list.append({'subject': subject, 'url': url})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 flat_url_list = []
# ----> 2 for subject, urls in data_dict.items():
#       3     for url in urls:
#       4         flat_url_list.append({'subject': subject, 'url': url})
#
# NameError: name 'data_dict' is not defined

# %%
OUTPUT_CSV_FILE = "heliyon_flatlist_time_retry.csv"
PAGE_LOAD_TIMEOUT_SECONDS = 30
URL_PROCESSING_WATCHDOG_SECONDS = 70 # Max time for one URL's scrape_article_details... call


if __name__ == "__main__":
    driver = initialize_uc_driver(headless=False, page_load_timeout_seconds=PAGE_LOAD_TIMEOUT_SECONDS)
    if not driver:
        print("Initial driver failed. Exiting.")
        exit()

    all_collected_data_this_run = []

    flat_url_list = []
    for subject, urls_for_subject in data_dict.items():
        for u in urls_for_subject:
            flat_url_list.append({'subject': subject, 'url': u})

    START_INDEX_FOR_RESUME = 3000

    current_flat_list_index = START_INDEX_FOR_RESUME
    while current_flat_list_index < len(flat_url_list):
        item_info = flat_url_list[current_flat_list_index]
        current_subject = item_info['subject']
        current_article_url = item_info['url']

        print(f"\n--- Attempting URL {current_flat_list_index + 1}/{len(flat_url_list)} ({current_subject}) ---")
        
        processing_start_time = time.time()
        details_dict = None
        driver_considered_ok = True

        try:
            details_dict = scrape_article_details_with_uc_and_bs4(current_article_url)
        except Exception as e_scraper_crash:
            print(f"  !!! UNEXPECTED CRASH IN scrape_article_details for {current_article_url}: {e_scraper_crash} !!!")
            details_dict = {"url": current_article_url, "title": f"ERROR_SCRAPER_CRASH: {type(e_scraper_crash).__name__}",
                            "abstract": "N/A", "keywords": [] }
            driver_considered_ok = False

        if details_dict:
            details_dict['subject'] = current_subject
            all_collected_data_this_run.append(details_dict)

        # --- Save to CSV after every 3000 items ---
        if len(all_collected_data_this_run) % 3000 == 0 and len(all_collected_data_this_run) > 0:
            df = pd.DataFrame(all_collected_data_this_run)
            csv_filename = f"heliyon_scraped_{current_flat_list_index+1}_rows.csv"
            df.to_csv(csv_filename, index=False, encoding='utf-8')
            print(f"\nSaved {len(all_collected_data_this_run)} items to '{csv_filename}'")

        processing_time_for_url = time.time() - processing_start_time

        if not driver_considered_ok or processing_time_for_url > URL_PROCESSING_WATCHDOG_SECONDS:
            if not driver_considered_ok:
                print(f"\n!!! Driver flagged as not OK for URL {current_article_url} (Result: {details_dict.get('title', 'N/A')}). Restarting. !!!")
            else:
                print(f"\n!!! WATCHDOG: URL {current_article_url} processing took {processing_time_for_url:.1f}s (>{URL_PROCESSING_WATCHDOG_SECONDS}s). Restarting driver. !!!")
            
            if driver:
                try: driver.quit()
                except: pass
            
            driver = initialize_uc_driver(headless=False, page_load_timeout_seconds=PAGE_LOAD_TIMEOUT_SECONDS)
            if not driver:
                print("CRITICAL: Failed to restart driver. Saving collected data and exiting.")
                break

            print("Driver restarted. Will re-try the current URL.")
            continue

        current_flat_list_index += 1
        time.sleep(0.1)
# Out:
# DEBUG: Initializing driver...
# DEBUG: Driver initialized. Page load timeout set to 30s.
#
# --- Attempting URL 3001/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)01248-3
#     Title: Optimization of anaerobic digestion parameters for biogas pr...
#     Abstract found: True (Length: 1460)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3002/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07150-0
#     Title: Optimizing energy storage plant discrete system dynamics ana...
#     Abstract found: True (Length: 1876)
#     Keywords found: True (Count: 4) -> ['GCN', 'Packet switching', 'Temporal depth-separated convolutional modules', 'Energy storage plants']
#
# --- Attempting URL 3003/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)12693-X
#     Title: COVID-19 impact on wind and solar energy sector and cost of ...
#     Abstract found: True (Length: 1400)
#     Keywords found: True (Count: 5) -> ['Coronavirus disease of 2019', 'Hybrid renewable energy system', 'Machine learning', 'Renewable energy', 'Techno-economic']
#
# --- Attempting URL 3004/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)03678-2
#     Title: Analysis of household LPG demand elasticity in Cameroon and ...
#     Abstract found: True (Length: 1374)
#     Keywords found: True (Count: 4) -> ['LPG consumption', 'Price and income elasticities', 'Urbanization', 'Cameroon']
#
# --- Attempting URL 3005/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)06364-3
#     Title: Thermohydraulic analysis of nanofluid flow in tubular heat e...
#     Abstract found: True (Length: 1573)
#     Keywords found: True (Count: 6) -> ['Heat transfer augmentation', 'Heat exchanger', 'Turbulators', 'Nanofluid', 'Numerical analysis']
#
# --- Attempting URL 3006/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08384-1
#     Title: Modelling, simulation, and measurement of solar power genera...
#     Abstract found: True (Length: 1910)
#     Keywords found: True (Count: 5) -> ['Modelling and simulation', 'Solar power generation', 'Design and operation', 'Explicit and implicit models', 'Differential models']
#
# --- Attempting URL 3007/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)04331-7
#     Title: Energy audit and associated carbon footprint estimation for ...
#     Abstract found: True (Length: 1342)
#     Keywords found: True (Count: 6) -> ['Brewery industry', 'Carbon footprint', 'Energy audit', 'Energy loss', 'Energy saving']
#
# --- Attempting URL 3008/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01249-X
#     Title: Mapping of solar energy potential in Fiji using an artificia...
#     Abstract found: True (Length: 2874)
#     Keywords found: True (Count: 5) -> ['Artificial neural network', 'ANN learning algorithms', 'Activation function', 'Solar radiation mapping', 'Coefficient of correlation']
#
# --- Attempting URL 3009/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)02115-6
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: A multi-fractured well performance model for unconventional ...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 6) -> ['Unconventional reservoirs', "Duong's model", "Extended Duong's model", 'Estimated ultimate recovery', 'Future performance prediction']
#
# --- Attempting URL 3010/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14139-4
#     Title: Performance analysis and prediction of a modified precompres...
#     Abstract found: True (Length: 1807)
#     Keywords found: True (Count: 4) -> ['Transcritical carbon dioxide', 'Power generation cycle', 'Performance analysis', 'Performance prediction']
#
# --- Attempting URL 3011/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15510-7
#     Title: Driver fatigue detection using PPG signal, facial features, ...
#     Abstract found: True (Length: 395)
#     Keywords found: True (Count: 5) -> ['Driver fatigue', 'PPG signals', 'LSTM model', 'Facial feature', 'Head posture']
#
# --- Attempting URL 3012/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14756-1
#     Title: A NIRS-based recognition of coal and rock using convolution-...
#     Abstract found: True (Length: 1367)
#     Keywords found: True (Count: 4) -> ['Coal and rock classification', 'Near-infrared spectrum', 'Improved broad learning system', 'Baseline correction']
#
# --- Attempting URL 3013/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14089-3
#     Title: Impact of urbanization and human development on ecological f...
#     Abstract found: True (Length: 1463)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3014/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14961-4
#     Title: Sustainable transformation of energy sector: Cluster analysi...
#     Abstract found: True (Length: 2123)
#     Keywords found: True (Count: 4) -> ['Energy sector', 'Sustainable transformation', 'Cluster analysis', 'Renewable energy']
#
# --- Attempting URL 3015/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07239-6
#     Title: Gas engine CCHP system optimization: An energy, exergy, econ...
#     Abstract found: True (Length: 1938)
#     Keywords found: True (Count: 8) -> ['Energy analysis', 'Exergy analysis', 'Economic assessment', 'Environmental impact assessment', 'System sizing']
#
# --- Attempting URL 3016/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)01879-6
#     Title: Early energy performance analysis of smart buildings by cons...
#     Abstract found: True (Length: 1825)
#     Keywords found: True (Count: 5) -> ['Energy performance', 'Smart buildings', 'Thermal loads', 'Prediction', 'Artificial intelligence']
#
# --- Attempting URL 3017/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08041-6
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Changes in power generation performance of an undershot cros...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 4) -> ['Hydraulic turbine of undershot cross-flow type', 'Irrigation channel', 'Snow masses', 'Turbine performance']
#
# --- Attempting URL 3018/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)05872-9
#     Title: Investigating the role of nuclear power and battery storage ...
#     Abstract found: True (Length: 736)
#     Keywords found: True (Count: 6) -> ['Grid scale battery storage', 'Hourly power system simulation for Central Europe', 'Nuclear energy', 'Renewable energy', 'Sensitivity analysis on effects of weather data']
#
# --- Attempting URL 3019/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)00158-4
#     Title: Forced flow cryogenic cooling in fusion devices: A review...
#     Abstract found: True (Length: 2209)
#     Keywords found: True (Count: 6) -> ['Fusion', 'Superconducting magnets', 'Cryogenics', 'Thermo-hydraulic', 'CICC']
#
# --- Attempting URL 3020/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)30154-7
#     Title: The co-combustion performance and reaction kinetics of refus...
#     Abstract found: True (Length: 1710)
#     Keywords found: True (Count: 14) -> ['Energy', 'Environmental science', 'Chemical engineering', 'Co-combustion', 'Discard coal']
#
# --- Attempting URL 3021/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(18)34482-7
#     Title: High-performance supercapacitors based on the carbon nanotub...
#     Abstract found: True (Length: 1319)
#     Keywords found: True (Count: 3) -> ['Materials science', 'Electrical engineering', 'Energy']
#
# --- Attempting URL 3022/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08207-5
#     Title: A multicriteria approach for biomass availability assessment...
#     Abstract found: True (Length: 1278)
#     Keywords found: True (Count: 5) -> ['Crop residues', 'AHP', 'TOPSIS', 'Multi-criteria decision making', 'Bioenergy']
#
# --- Attempting URL 3023/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(19)36504-1
#     Title: Public perception of carbon capture and storage: A state-of-...
#     Abstract found: True (Length: 2004)
#     Keywords found: True (Count: 14) -> ['Public perception', 'Carbon capture and storage', 'CCS', 'Review', 'Sustainable development']
#
# --- Attempting URL 3024/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)02637-2
#     Title: Evaluation of different models for validating of photovoltai...
#     Abstract found: True (Length: 1321)
#     Keywords found: True (Count: 4) -> ['Photovoltaic module', 'Module temperature', 'Prediction models', 'Temperature measured']
#
# --- Attempting URL 3025/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15891-4
#     Title: Techno-economic and sustainability assessment of the power t...
#     Abstract found: True (Length: 931)
#     Keywords found: True (Count: 5) -> ['Power-to-X', 'Sustainability', 'CO2hydrogenation', 'Economic assessment', 'Methanol production']
#
# --- Attempting URL 3026/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)16792-8
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Effects of surface curvature on rain erosion of wind turbine...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 5) -> ['Wind turbine blade', 'Water droplet', 'High-velocity impact', 'Surface curvature', 'Dynamic response']
#
# --- Attempting URL 3027/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10248-4
#     Title: Energy consumption and thermal comfort of rock-cut and moder...
#     Abstract found: True (Length: 1895)
#     Keywords found: True (Count: 5) -> ['Indoor thermal comfort', 'Energy consumption', 'Rock-cut architecture', 'Meymand', 'Vernacular architecture']
#
# --- Attempting URL 3028/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(18)32931-1
#     Title: Numerical investigation of dimensions and arrangement of obs...
#     Abstract found: True (Length: 1267)
#     Keywords found: True (Count: 3) -> ['Electrochemistry', 'Energy', 'Mechanics']
#
# --- Attempting URL 3029/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03905-6
#     Title: Renewable energy communities or ecosystems: An analysis of s...
#     Abstract found: True (Length: 1812)
#     Keywords found: True (Count: 6) -> ['Collaborative networks', 'Energy ecosystems', 'Peer-to-peer energy exchange', 'Sharing economy', 'Renewable energy communities']
#
# --- Attempting URL 3030/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11762-8
#     Title: Comparative study of hybrid, tri-hybrid and tetra-hybrid nan...
#     Abstract found: True (Length: 2186)
#     Keywords found: True (Count: 6) -> ['Tetra-hybrid nanofluid', 'Cross-diffusion effects', 'Multiple slip', 'Arrhenius activation energy', 'Sensitivity analysis']
#
# --- Attempting URL 3031/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09977-8
#     Title: An adaptable method for efficient modeling of photovoltaic g...
#     Abstract found: True (Length: 1442)
#     Keywords found: True (Count: 6) -> ['PV module', 'PV modeling', 'Two-diode model', 'Parameter extraction', 'Energy conversion']
#
# --- Attempting URL 3032/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)06932-3
#     Title: Optimal power control in Renewable Energy sources using Inte...
#     Abstract found: True (Length: 1327)
#     Keywords found: True (Count: 5) -> ['Sliding mode control', 'Artificial neural network', 'Adaptive neuro-fuzzy inference system', 'Hybrid renewable energy system', 'Xilinx power management system']
#
# --- Attempting URL 3033/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)32234-9
#     Title: Carboxymethyl cellulose-based polyelectrolyte as cationic ex...
#     Abstract found: True (Length: 1106)
#     Keywords found: True (Count: 13) -> ['Chemical engineering', 'Energy', 'Materials science', 'Chemical energy storage', 'Electrochemical energy engineering']
#
# --- Attempting URL 3034/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01917-X
#     Title: Transient performance prediction of solar dish concentrator ...
#     Abstract found: True (Length: 1746)
#     Keywords found: True (Count: 5) -> ['Dish concentrator', 'Stirling engine', 'Small-scale irrigation', 'Transient analysis', 'Thermoelectric generator']
#
# --- Attempting URL 3035/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)00684-9
#     Title: Design and optimization of four-terminal mechanically stacke...
#     Abstract found: True (Length: 1565)
#     Keywords found: True (Count: 6) -> ['HTM-Free perovskite PV cells', 'Crystalline silicon solar cells', 'Mechanically stacked four-terminal tandem', 'Optically coupled four-terminal tandem', 'SCAPS-1D']
#
# --- Attempting URL 3036/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15186-9
#     Title: Comparative analysis of life cycle assessment of biogas-powe...
#     Abstract found: True (Length: 1600)
#     Keywords found: True (Count: 6) -> ['Biogas', 'Biogas power', 'Coal power', 'Anaerobic digestion', 'Environmental emissions']
#
# --- Attempting URL 3037/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)30131-6
#     Title: Performance evaluation of an indirect air cooling system com...
#     Abstract found: True (Length: 1942)
#     Keywords found: True (Count: 10) -> ['Agriculture', 'Energy', 'Food science', 'Industrial engineering', 'Relative humidity']
#
# --- Attempting URL 3038/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)01122-1
#     Title: Development of solar cell for large area position detection:...
#     Abstract found: True (Length: 1510)
#     Keywords found: True (Count: 8) -> ['Solar cell', 'Large active area motion detector', 'Position sensitive detector', 'PSD', 'Output display']
#
# --- Attempting URL 3039/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(18)37866-6
#     Title: Experimental investigation on convective heat transfer and p...
#     Abstract found: True (Length: 1310)
#     Keywords found: True (Count: 3) -> ['Energy', 'Mechanical engineering', 'Nanotechnology']
#
# --- Attempting URL 3040/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07630-8
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: A static rooftop shading system for year-round thermal comfo...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 5) -> ['Passive strategies', 'Indoor temperature', 'Rooftop strategies', 'Adaptive thermal comfort', 'Energy simulations']
#
# --- Attempting URL 3041/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14200-4
#     Title: Parametric optimization for the performance analysis of nove...
#     Abstract found: True (Length: 1359)
#     Keywords found: True (Count: 5) -> ['Hybrid solar cell', 'Organic-inorganic perovskite', 'Spiro-OMeTAD', 'SCAPS-1D', 'Shallow acceptor density']
#
# --- Attempting URL 3042/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)07809-X
#     Title: Performance evaluation of ZnSnN2 solar cells with Si back su...
#     Abstract found: True (Length: 1984)
#     Keywords found: True (Count: 6) -> ['ZnSnN2', 'Silicon', 'SCAPS 1D', 'Thin films', 'Thickness']
#
# --- Attempting URL 3043/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09646-4
#     Title: Glucose-based biofuel cells and their applications in medica...
#     Abstract found: True (Length: 1273)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3044/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11418-1
#     Title: Optimization and analysis of battery thermal management syst...
#     Abstract found: True (Length: 1377)
#     Keywords found: True (Count: 5) -> ['Lithium-ion batteries', 'Flat heat pipe', 'Heat dissipation fins', 'Orthogonal experiment', 'Fuzzy grey relational analysis']
#
# --- Attempting URL 3045/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15001-3
#     Title: Biomass power plant prospects in Indonesia’s energy transiti...
#     Abstract found: True (Length: 1693)
#     Keywords found: True (Count: 6) -> ['Renewable energy', 'Renewable energy tariffs', 'Energy transition', 'Biomass', 'Indonesia']
#
# --- Attempting URL 3046/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(25)00448-7
#     Title: Comparative potential of biogas production from the distille...
#     Abstract found: True (Length: 1914)
#     Keywords found: True (Count: 3) -> ['Co-digestion', 'Distillery waste', 'Fruit-vegetable waste and methane yield']
#
# --- Attempting URL 3047/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)14606-3
#     Title: Short-term interactions between Longmaxi shale and carbon di...
#     Abstract found: True (Length: 2877)
#     Keywords found: True (Count: 6) -> ['Longmaxi shale', 'Supercritical carbon dioxide', 'Waterless fracturing', 'Mechanical property', 'Water-rock interaction']
#
# --- Attempting URL 3048/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08578-X
#     Title: A new method for evaluating the heat leak of cryogenic vesse...
#     Abstract found: True (Length: 1117)
#     Keywords found: True (Count: 5) -> ['Cryogenic vessel', 'Heat leak', 'Self-pressurization', 'Vapor temperature', 'Boil off gas']
#
# --- Attempting URL 3049/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)12787-9
#     Title: Cold flow properties of biodiesel from waste cooking oil and...
#     Abstract found: True (Length: 1342)
#     Keywords found: True (Count: 5) -> ['Biodiesel', 'Cold flow properties', 'Eversa 2.0', 'WCO', 'Optimization']
#
# --- Attempting URL 3050/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)30163-8
#     Title: Feasibility study on small cars as an alternative to convent...
#     Abstract found: True (Length: 1470)
#     Keywords found: True (Count: 8) -> ['Energy', 'Automotive engineering', 'Combustion engine', 'Energy economics', 'Urban energy consumption']
#
# --- Attempting URL 3051/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00212-3
#     Title: Improved super-twisting sliding mode control strategy in per...
#     Abstract found: True (Length: 1155)
#     Keywords found: True (Count: 4) -> ['Sliding mode control', 'Permanent magnet synchronous motor', 'Hydrogen fuel cell', 'Super-twisting algorithm']
#
# --- Attempting URL 3052/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03186-3
#     Title: Simulation of mixed-mode solar dryer with vertical air distr...
#     Abstract found: True (Length: 949)
#     Keywords found: True (Count: 6) -> ['Simulation', 'Drying', 'Injera', 'Mixed-mode solar dryer', 'CFD']
#
# --- Attempting URL 3053/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)13866-2
#     Title: Short-term photovoltaic forecasting model with parallel mult...
#     Abstract found: True (Length: 1016)
#     Keywords found: True (Count: 4) -> ['Prediction', 'PV', 'LSDBO algorithm', 'Parallel multi-channel']
#
# --- Attempting URL 3054/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)17028-4
#     Title: Renewable energy transition in Europe in the context of rene...
#     Abstract found: True (Length: 2039)
#     Keywords found: True (Count: 5) -> ['Energy transition', 'Renewable energy', 'Green hydrogen', 'Decarbonization', 'Europe']
#
# --- Attempting URL 3055/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)03742-8
#     Title: Performance study on a solar concentrator system for water d...
#     Abstract found: True (Length: 1390)
#     Keywords found: True (Count: 5) -> ['Distilled water', 'Nanofluid', 'Solar energy', 'Solar concentrator system', 'Thermal efficiency']
#
# --- Attempting URL 3056/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(17)32755-X
#     Title: A group decision making tool for assessing climate policy ri...
#     Abstract found: True (Length: 1187)
#     Keywords found: True (Count: 3) -> ['Industrial engineering', 'Energy', 'Computer science']
#
# --- Attempting URL 3057/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08636-X
#     Title: Factors affecting energy efficiency in herringbone and rotar...
#     Abstract found: True (Length: 1393)
#     Keywords found: True (Count: 6) -> ['Energy efficiency', 'Milking efficiency', 'Herringbone milking parlour', 'Rotary milking parlour', 'Correlation analysis']
#
# --- Attempting URL 3058/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)31470-5
#     Title: The role of diversity, reserve margin and system structure o...
#     Abstract found: True (Length: 1086)
#     Keywords found: True (Count: 7) -> ['Economics', 'Energy', 'Resilience', 'Electricity diversity', 'Spare capacity']
#
# --- Attempting URL 3059/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08203-8
#     Title: Optimum utilization of hub energy micro-grids with micro-net...
#     Abstract found: True (Length: 1509)
#     Keywords found: True (Count: 4) -> ['Biogas', 'Flexible operation', 'Hub', 'Micro-grids,GAMS']
#
# --- Attempting URL 3060/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03331-X
#     Title: SnTe as a BSF enhances the performance of Sb2Se3 based solar...
#     Abstract found: True (Length: 1102)
#     Keywords found: True (Count: 5) -> ['Sb2Se3', 'BSF', 'SnTe', 'Solar cell', 'SCAPS-1D']
#
# --- Attempting URL 3061/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(17)31254-9
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: An assessment of the potential for the development of the sh...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 2) -> ['Economics', 'Energy']
#
# --- Attempting URL 3062/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04841-7
#     Title: Resurrection of carbon dioxide as refrigerant in solar therm...
#     Abstract found: True (Length: 2272)
#     Keywords found: True (Count: 5) -> ['CO2air conditioning', 'Natural refrigerant', 'TRNSYS', 'R-744', 'Absorption cooling']
#
# --- Attempting URL 3063/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)31544-9
#     Title: Evaluating LEED commercial interior (LEED-CI) projects under...
#     Abstract found: True (Length: 1162)
#     Keywords found: True (Count: 9) -> ['Construction engineering', 'Energy use in building', 'Environmental analysis', 'Environmental assessment', 'Environmental impact assessment']
#
# --- Attempting URL 3064/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09975-4
#     Title: RETRACTED: Hierarchical deep reinforcement learning for self...
#     Abstract found: True (Length: 157)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3065/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)02743-8
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Early thermal aging detection in tin based perovskite solar ...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 6) -> ['Tin-based perovskite', 'Solar cell', 'Early aging detection', 'Single diode model', 'Series resistance']
#
# --- Attempting URL 3066/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)13267-7
#     Title: New single-switch buck–boost converter with continuous input...
#     Abstract found: True (Length: 1203)
#     Keywords found: True (Count: 5) -> ['Buck-boost', 'DC-DC converter', 'Wide conversion ratio', 'High step-up', 'Single-switch']
#
# --- Attempting URL 3067/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)09568-3
#     Title: Industrial policies of integrated energy services in China: ...
#     Abstract found: True (Length: 1027)
#     Keywords found: True (Count: 5) -> ['Integrated energy services', 'Energy restructuring', 'Industrial policy', 'Government intervention', 'Qualitative analysis research']
#
# --- Attempting URL 3068/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03184-X
#     Title: Floating photovoltaics performance simulation approach...
#     Abstract found: True (Length: 558)
#     Keywords found: True (Count: 5) -> ['Floating photovoltaics (FPV)', 'Solar tracking', 'FPV design', 'Energy yield', 'Techno-economic analysis']
#
# --- Attempting URL 3069/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11211-X
#     Title: Study of a grid-connected floating photovoltaic power plant ...
#     Abstract found: True (Length: 1369)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3070/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)01885-6
#     Title: Modeling and control of a photovoltaic-wind hybrid microgrid...
#     Abstract found: True (Length: 1183)
#     Keywords found: True (Count: 5) -> ['BESS', 'GA-ANFIS', 'Perturb and observe (P&O)', 'Photovoltaic', 'PV-Wind hybrid model']
#
# --- Attempting URL 3071/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)02923-7
#     Title: High efficiency Cu2MnSnS4 thin film solar cells with SnS BSF...
#     Abstract found: True (Length: 1474)
#     Keywords found: True (Count: 5) -> ['Solar cell', 'Simulation', 'Cu2MnSnS4', 'SnS', 'SCAPS-1D']
#
# --- Attempting URL 3072/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01868-0
#     Title: Enhancement of anaerobic digestion by co-digesting food wast...
#     Abstract found: True (Length: 2986)
#     Keywords found: True (Count: 5) -> ['Anaerobic digestion', 'Co-digestion', 'Food waste', 'Mesophilic', 'Water hyacinth']
#
# --- Attempting URL 3073/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10001-1
#     Title: RETRACTED: Assessing the influence of tourism development, v...
#     Abstract found: True (Length: 157)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3074/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15894-X
#     Title: The sufficiency-based, the de-growth, and the official – Cri...
#     Abstract found: True (Length: 1489)
#     Keywords found: True (Count: 6) -> ['Sufficiency', 'De-growth economy', 'Strong sustainability', 'Energy dependence', 'Electricity sector']
#
# --- Attempting URL 3075/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)01989-8
#     Title: Impact of ZnO nanoparticles as additive on performance and e...
#     Abstract found: True (Length: 2225)
#     Keywords found: True (Count: 5) -> ['Waste plastic oil', 'ZnO nanoparticles', 'Diesel engine', 'Emission', 'Performance']
#
# --- Attempting URL 3076/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(25)00958-2
#     Title: Performance and suitability analysis of rooftop solar PV in ...
#     Abstract found: True (Length: 2405)
#     Keywords found: True (Count: 6) -> ['Rooftop solar PV', 'Performance analysis', 'Levelized cost of electricity', 'System advisor model', 'Policy frameworks']
#
# --- Attempting URL 3077/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04157-9
#     Title: RETRACTED: Utilization of additives in biodiesel blends for ...
#     Abstract found: True (Length: 157)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3078/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)04300-7
#     Title: A roadmap for the implementation of a renewable energy commu...
#     Abstract found: True (Length: 1440)
#     Keywords found: True (Count: 6) -> ['Renewable energy communities', 'Energy sharing', 'Energy management', 'Energy systems', 'Roadmap of renewable energy community']
#
# --- Attempting URL 3079/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(19)30152-5
#     Title: Integration of PV floating with hydroelectric power plants...
#     Abstract found: True (Length: 829)
#     Keywords found: True (Count: 5) -> ['Electrical engineering', 'Energy', 'Photovoltaic', 'Floating systems', 'Hydroelectric power plant']
#
# --- Attempting URL 3080/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00791-6
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Dynamic optimisation of unbalanced distribution network mana...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 6) -> ['Model predictive control', 'Economic dispatch', 'Distributed generation', 'Renewable energy sources', 'Markov process']
#
# --- Attempting URL 3081/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)31756-4
#     Title: Development and comparison of migration paths for smart grid...
#     Abstract found: True (Length: 1701)
#     Keywords found: True (Count: 11) -> ['Electrical engineering', 'Energy', 'Environmental science', 'Environmental economics', 'Environmental engineering']
#
# --- Attempting URL 3082/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)09565-8
#     Title: Smart contracts and homomorphic encryption for private P2P e...
#     Abstract found: True (Length: 1802)
#     Keywords found: True (Count: 6) -> ['Blockchain', 'Privacy', 'Smart contracts', 'Encrypted data', 'P2P energy trading']
#
# --- Attempting URL 3083/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)02746-3
#     Title: Development of a wind turbine for a hybrid solar-wind power ...
#     Abstract found: True (Length: 1578)
#     Keywords found: True (Count: 5) -> ['Wind turbine', 'Renewable energy', 'Machine design', 'Local content', 'Soil moisture']
#
# --- Attempting URL 3084/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)01749-7
#     Title: Decommissioning of oil and gas assets: industrial and enviro...
#     Abstract found: True (Length: 478)
#     Keywords found: True (Count: 10) -> ['Oil and gas assets', 'Decommissioning', 'Industrial and environmental security', 'Environmental protection', 'Safety']
#
# --- Attempting URL 3085/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)02248-4
#     Title: Engineering nanostructured Ag doped α-MnO2 electrocatalyst f...
#     Abstract found: True (Length: 1322)
#     Keywords found: True (Count: 5) -> ['Silver', 'Manganese dioxide', 'Oxygen reduction reaction', 'Co-precipitation approach', 'Zinc-air battery']
#
# --- Attempting URL 3086/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)05285-X
#     Title: Physics-informed NN-based adaptive backstepping terminal sli...
#     Abstract found: True (Length: 1426)
#     Keywords found: True (Count: 4) -> ['Adaptive backstepping terminal sliding mode controller', 'Buck power converter control', 'PEM electrolyzer', 'Physics-informed neural network (PINN)']
#
# --- Attempting URL 3087/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)00009-9
#     Title: Fuzzy-based prediction of solar PV and wind power generation...
#     Abstract found: True (Length: 1685)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3088/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)13716-4
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Rule-based energy management strategies for PEMFC-based micr...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 5) -> ['Micro-CHP', 'EMS', 'Techno-economic model', 'PEMFC', 'Operating strategy']
#
# --- Attempting URL 3089/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11495-8
#     Title: Worldwide developments and challenges for solar pyrolysis...
#     Abstract found: True (Length: 730)
#     Keywords found: True (Count: 9) -> ['Solar pyrolysis', 'Solar biofuels', 'Pyrolysis', 'Concentrated solar energy', 'Solar reactor']
#
# --- Attempting URL 3090/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00738-2
#     Title: Mechanism and kinetic of piezo-catalytic desulfurization of ...
#     Abstract found: True (Length: 1795)
#     Keywords found: True (Count: 5) -> ['Piezo-desulfurization', 'Model fuel', 'Kerosene', 'CexOy/SrO nanocomposite', 'Piezo']
#
# --- Attempting URL 3091/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)07761-7
#     Title: Optimal evaluation of crop residues for gasification in Ghan...
#     Abstract found: True (Length: 2347)
#     Keywords found: True (Count: 6) -> ['Crop residues', 'MCDM', 'Gasification', 'VIKOR', 'TOPSIS']
#
# --- Attempting URL 3092/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)00209-8
#     Title: Facial preparation of covalent modified reduced graphene oxi...
#     Abstract found: True (Length: 1712)
#     Keywords found: True (Count: 4) -> ['Modified reduced graphene oxide', 'Polyaniline', 'Supercapacitors', 'Electrochemical performance']
#
# --- Attempting URL 3093/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)03917-8
#     Title: Drivers and challenges of off-grid renewable energy-based pr...
#     Abstract found: True (Length: 925)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3094/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)03713-7
#     Title: Energy markets restructure beyond 2022 and its implications ...
#     Abstract found: True (Length: 2175)
#     Keywords found: True (Count: 4) -> ['LNG', 'Time series model', 'Exponential smoothing', 'And natural gas pricing']
#
# --- Attempting URL 3095/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)02927-X
#     Title: Numerical study of copper antimony sulphide (CuSbS2) solar c...
#     Abstract found: True (Length: 1124)
#     Keywords found: True (Count: 4) -> ['CuSbS2', 'SCAPS-1D', 'Thin film', 'Simulation']
#
# --- Attempting URL 3096/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07706-5
#     Title: Day-ahead resilience-economic energy management and feeder r...
#     Abstract found: True (Length: 2580)
#     Keywords found: True (Count: 6) -> ['Combined cooling heat and power unit', 'Energy management', 'Microgrids', 'Reconfiguration', 'Resilience']
#
# --- Attempting URL 3097/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00018-5
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Business decision-making of power generators in competitive ...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 5) -> ['Power plant valuation', 'Optimal power sales strategy', 'Risk hedging', 'Trinomial tree', 'Dynamic programming principle']
#
# --- Attempting URL 3098/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)00229-8
#     Title: The influence of renewable energy usage on consumption-based...
#     Abstract found: True (Length: 1593)
#     Keywords found: True (Count: 5) -> ['Consumption-based carbon emissions', 'Globalization', 'Renewable energy', 'Economic growth', 'MINT Economies']
#
# --- Attempting URL 3099/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08573-0
#     Title: Comparison of machine learning algorithms for predicting die...
#     Abstract found: True (Length: 1714)
#     Keywords found: True (Count: 5) -> ['Machine learning techniques', 'Fuel blends', 'Brake thermal efficiency', 'Brake-specific fuel consumption', 'Exhaust emissions']
#
# --- Attempting URL 3100/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04834-X
#     Title: A review of the techno-economic potential and environmental ...
#     Abstract found: True (Length: 2590)
#     Keywords found: True (Count: 6) -> ['Solar parabolic trough collector', 'Geometric analysis', 'Thermal analysis', 'Heat transfer enhancement', 'Heat transfer fluid']
#
# --- Attempting URL 3101/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)02342-2
#     Title: Enhancement of wind energy conversion system performance usi...
#     Abstract found: True (Length: 1412)
#     Keywords found: True (Count: 6) -> ['Wind energy', 'Blade angle controller', 'Fractional calculus', 'Adaptive PI', 'Adaptive fractional order PI']
#
# --- Attempting URL 3102/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)01119-1
#     Title: Solar energy: A panacea for the electricity generation crisi...
#     Abstract found: True (Length: 1672)
#     Keywords found: True (Count: 6) -> ['Renewable energy', 'Solar energy', "Nigeria's electricity generation", 'Photovoltaics', 'Solar radiation']
#
# --- Attempting URL 3103/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)01193-2
#     Title: Income and energy consumption in Asia-Pacific countries – A ...
#     Abstract found: True (Length: 1254)
#     Keywords found: True (Count: 4) -> ['Energy consumption', 'Income', 'Panel cointegration and causality', 'Common factors']
#
# --- Attempting URL 3104/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08702-9
#     Title: Engine combustion modeling method based on hybrid drive...
#     Abstract found: True (Length: 1300)
#     Keywords found: True (Count: 4) -> ['Diesel engine', 'Prediction model', '0-D model', 'Deep learning']
#
# --- Attempting URL 3105/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(18)35506-3
#     Title: Energy efficiency measures in buildings for achieving sustai...
#     Abstract found: True (Length: 1103)
#     Keywords found: True (Count: 2) -> ['Economics', 'Energy']
#
# --- Attempting URL 3106/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00754-0
#     Title: Multiple-criteria decision analysis techniques for anaerobic...
#     Abstract found: True (Length: 2135)
#     Keywords found: True (Count: 6) -> ['AHP method', 'Anaerobic digester', 'Multi-criteria decision analysis', 'Smallholder farm', 'SMART method']
#
# --- Attempting URL 3107/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08706-6
#     Title: Targeting high performance of perovskite solar cells by comb...
#     Abstract found: True (Length: 1524)
#     Keywords found: True (Count: 5) -> ['Perovskite solar cell', 'Machine learning', 'Random forest technique', 'Prediction', 'Optimization']
#
# --- Attempting URL 3108/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(21)01441-9
#     Title: Effect of substrate ratios on the simultaneous carbon, nitro...
#     Abstract found: True (Length: 1388)
#     Keywords found: True (Count: 5) -> ['Bioenergy', 'Columbic efficiency', 'Electronic equivalents', 'Substrate ratios', 'Voltage generation']
#
# --- Attempting URL 3109/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08950-3
#     Title: Experimental investigation of multi-step airfoils in low Rey...
#     Abstract found: True (Length: 1724)
#     Keywords found: True (Count: 6) -> ['Stepped NACA23012C airfoil', 'Reynolds number sensitivity', 'Experimental investigations', 'Computational fluid dynamics', 'Aerospace engineering']
#
# --- Attempting URL 3110/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08047-7
#     Title: RETRACTED: Hybrid wavelet/Elman NN model for short term cost...
#     Abstract found: True (Length: 157)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3111/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)07766-6
#     Title: Outstanding conversion efficiency of 38.39% from a Perovskit...
#     Abstract found: True (Length: 1855)
#     Keywords found: True (Count: 7) -> ['Clean energy', 'Lead-free perovskite', 'CIGS', 'Tandem PV cell', 'ETL']
#
# --- Attempting URL 3112/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03636-2
#     Title: Compatibility optimization of a polyhedral-shape thermoelect...
#     Abstract found: True (Length: 1437)
#     Keywords found: True (Count: 5) -> ['Heat exchanger', 'Thermoelectric generator', 'Fin parameters', 'Compatibility', 'Multi-objective grey wolf optimizer']
#
# --- Attempting URL 3113/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)09469-0
#     Title: Techno-economic analysis and environmental impact assessment...
#     Abstract found: True (Length: 1580)
#     Keywords found: True (Count: 5) -> ['Microwave-assisted pyrolysis', 'Pine sawdust', 'Bio-oil esterification', 'Biodiesel', 'Techno-economic analysis']
#
# --- Attempting URL 3114/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09020-0
#     Title: Sulfurization of bimetallic (Co and Fe) oxide and alloy deco...
#     Abstract found: True (Length: 1668)
#     Keywords found: True (Count: 6) -> ['OER', 'HER', 'MWCNTs', 'Electrocatalysis', 'Water splitting']
#
# --- Attempting URL 3115/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10888-2
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Optimizing quasi-dynamic wireless charging for urban electri...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 4) -> ['Chance-constrained optimization', 'Electric vehicles', 'Optimal siting', 'Quasi-dynamic wireless charging']
#
# --- Attempting URL 3116/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08910-7
#     Title: A2LiGaI6 (A = Cs, Rb): New lead-free and direct bandgap hali...
#     Abstract found: True (Length: 1424)
#     Keywords found: True (Count: 7) -> ['Optical properties', 'Photoelectric', 'Solar cell', 'Density functional theory', 'TB-mBJ']
#
# --- Attempting URL 3117/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)05382-3
#     Title: Passive solar tracker using a bimetallic strip activator wit...
#     Abstract found: True (Length: 1524)
#     Keywords found: True (Count: 5) -> ['Bimetallic strip', 'Night return mechanism', 'Passive solar tracker', 'Potential energy', 'Solenoid valve']
#
# --- Attempting URL 3118/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08140-4
#     Title: Comparative assessment of emissions, performance, and econom...
#     Abstract found: True (Length: 1348)
#     Keywords found: True (Count: 7) -> ['Combustion engine', 'Dual', 'Fuel', 'Efficiency', 'Emissions']
#
# --- Attempting URL 3119/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08743-7
#     Title: Economic and technical analysis of an HRES (Hybrid Renewable...
#     Abstract found: True (Length: 1616)
#     Keywords found: True (Count: 5) -> ['Sustainable energy', 'Hybrid renewable energy systems (HRES)', 'Improved subtraction-average-based optimizer (ISABO)', 'HOMER', 'PV']
#
# --- Attempting URL 3120/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)02200-4
#     Title: Small hydropower generation using pump as turbine; a smart s...
#     Abstract found: True (Length: 1617)
#     Keywords found: True (Count: 6) -> ['Pump-as-turbine', 'Small hydropower', 'Renewable energy', 'Environment friendly', 'Energy resources']
#
# --- Attempting URL 3121/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)12979-9
#     Title: EnergyShare AI: Transforming P2P energy trading through adva...
#     Abstract found: True (Length: 1133)
#     Keywords found: True (Count: 7) -> ['Peer-to-peer energy exchange', 'Deep learning', 'Energy storage systems', 'Solar power systems', 'Electric vehicles']
#
# --- Attempting URL 3122/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(18)34324-X
#     Title: Studies of different types of insulating oils and their mixt...
#     Abstract found: True (Length: 1291)
#     Keywords found: True (Count: 2) -> ['Electrical engineering', 'Energy']
#
# --- Attempting URL 3123/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07450-4
# NO ABSTRACT, HELP!!!!@@@!!
#     Title: Optimal scheduler for energy consumption reduction in multi-...
#     Abstract found: False (Length: 3)
#     Keywords found: True (Count: 6) -> ['Optimal scheduling', 'Multi-vector energy manager system', 'Flexibility', 'Cranes', 'EV charging station']
#
# --- Attempting URL 3124/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01382-2
#     Title: Converting data into knowledge with RCA methodology improved...
#     Abstract found: True (Length: 1252)
#     Keywords found: True (Count: 4) -> ['Failure mode', 'Inverters', 'Knowledge management', 'Solar plant']
#
# --- Attempting URL 3125/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(20)31296-2
#     Title: Future research tendencies for solar energy management using...
#     Abstract found: True (Length: 724)
#     Keywords found: True (Count: 7) -> ['Energy', 'Green engineering', 'Sustainable development', 'Energy management', 'Solar energy']
#
# --- Attempting URL 3126/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)13253-7
#     Title: Asymmetric gas diffusion layers for improved water managemen...
#     Abstract found: True (Length: 1084)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 3127/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)16450-X
#     Title: Numerical study on inter-particle effects for multiple react...
#     Abstract found: True (Length: 1814)
#     Keywords found: True (Count: 5) -> ['Coal', 'Biomass', 'Co-firing', 'Morphology', 'Group effects']
#
# --- Attempting URL 3128/12212 (energy) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)04391-3
# ...
#     Abstract found: True (Length: 1259)
#     Keywords found: True (Count: 5) -> ['COVID-19', 'Coronavirus', 'Gut lung axis', 'ACE2', 'Gut microbiome']
#
# --- Attempting URL 12171/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09145-X
#     Title: Ceftolozane/tazobactam: Literature review of its activity on...
#     Abstract found: True (Length: 263)
#     Keywords found: True (Count: 5) -> ['Ceftolozane', 'Ceftolozane/tazobactam', 'Enterobacterales', 'Pseudomonas aeruginosa,susceptibility', 'Taiwan']
#
# --- Attempting URL 12172/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)01821-8
#     Title: Hepatitis B virus infection (HBV) and HIV-HBV coinfection am...
#     Abstract found: True (Length: 189)
#     Keywords found: True (Count: 6) -> ['HIV', 'Hepatitis', 'Hepatitis B virus', 'Zimbabwe', 'Men who have sex with men']
#
# --- Attempting URL 12173/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08284-7
#     Title: Risk factors for ICU-acquired weakness in sepsis patients: A...
#     Abstract found: True (Length: 233)
#     Keywords found: True (Count: 5) -> ['Sepsis', 'Intensive care unit', 'Acquired weakness', 'Risk factors', 'Diagnostic threshold']
#
# --- Attempting URL 12174/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08018-6
#     Title: Alpha and gamma mangostins inhibit wild-type B SARS-CoV-2 mo...
#     Abstract found: True (Length: 317)
#     Keywords found: True (Count: 7) -> ['Alpha mangostin', 'Gamma mangostin', '3C-like protease', 'Antiviral drug discovery', 'SARS-CoV-2 drugs']
#
# --- Attempting URL 12175/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)05293-3
#     Title: COVID-19 pneumonia: Perfusion abnormalities shown on subtrac...
#     Abstract found: True (Length: 134)
#     Keywords found: True (Count: 5) -> ['COVID-19', 'Computed tomography angiography', 'Angiotensin converting enzyme 2', 'Vasoconstriction', 'Ventilation-perfusion ratio']
#
# --- Attempting URL 12176/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10355-6
#     Title: Human brucellosis and associated risk factors in the Middle ...
#     Abstract found: True (Length: 146)
#     Keywords found: True (Count: 5) -> ['Human brucellosis', 'Middle Eastern countries', 'Risk factors', 'Meta-analysis', 'Unpasteurized dairy products']
#
# --- Attempting URL 12177/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)10686-4
#     Title: Comparison of neutralization potency across passive immunoth...
#     Abstract found: True (Length: 1589)
#     Keywords found: True (Count: 5) -> ['Emerging diseases', 'Passive immunotherapy', 'Plasma therapy', 'Neutralizing antibodies', 'Purified antibody']
#
# --- Attempting URL 12178/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11701-X
#     Title: Tuberculosis patients with diabetes co-morbidity experience ...
#     Abstract found: True (Length: 157)
#     Keywords found: True (Count: 6) -> ['Tuberculosis', 'Diabetes', 'Treatment monitoring', 'TB-Molecular bacterial load assay', 'Bacterial clearance']
#
# --- Attempting URL 12179/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)06417-4
#     Title: Stress impact of COVID-19 in nurse managers...
#     Abstract found: True (Length: 120)
#     Keywords found: True (Count: 5) -> ['Nurse managers', 'Stress', 'Workload', 'COVID-19', 'Hospitals']
#
# --- Attempting URL 12180/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)06018-3
#     Title: Dynamics of respiratory infectious diseases under rapid urba...
#     Abstract found: True (Length: 308)
#     Keywords found: True (Count: 4) -> ['Urbanization', 'Infectious diseases', 'Respiratory infectious diseases', 'COVID-19']
#
# --- Attempting URL 12181/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)09191-0
#     Title: Can mean platelet volume be a prognosis predictor in viral i...
#     Abstract found: True (Length: 236)
#     Keywords found: True (Count: 3) -> ['Mean platelet volume', 'COVID-19', 'Prognosis']
#
# --- Attempting URL 12182/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15075-X
#     Title: Clinical characteristics of SARS-CoV-2 Omicron pneumonia in ...
#     Abstract found: True (Length: 379)
#     Keywords found: True (Count: 4) -> ['COVID-19', 'Immunocompromised', 'Immunocompetent', 'Prognosis']
#
# --- Attempting URL 12183/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)06312-6
#     Title: A nomogram to predict cryptococcal meningitis in patients wi...
#     Abstract found: True (Length: 489)
#     Keywords found: True (Count: 5) -> ['Nomograms', 'Cryptococcosis', 'Meningitis', 'Pulmonary', 'Regression analysis']
#
# --- Attempting URL 12184/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01256-7
#     Title: Assessment of intestinal and blood protozoan infections amon...
#     Abstract found: True (Length: 405)
#     Keywords found: True (Count: 4) -> ['Intestinal protozoans', 'Pregnant women', 'Toxoplasma gondiiantibodies', 'Malaria infection']
#
# --- Attempting URL 12185/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)06992-5
#     Title: Droplet digital PCR aids in the diagnosis of children with f...
#     Abstract found: True (Length: 1123)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 12186/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)00539-5
#     Title: Obesity and diabetes mellitus are associated with SARS-CoV-2...
#     Abstract found: True (Length: 1153)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 12187/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04391-8
#     Title: Pathogenic Nocardia amamiensis infection: A rare case report...
#     Abstract found: True (Length: 380)
#     Keywords found: True (Count: 6) -> ['Nocardia', 'Nocardia amamiensis', 'Pulmonary infection', 'Clinical characteristics', 'Diagnosis']
#
# --- Attempting URL 12188/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03465-X
#     Title: Risk assessment of SARS-CoV-2 transmission in hospitality em...
#     Abstract found: True (Length: 427)
#     Keywords found: True (Count: 3) -> ['SARS-CoV-2', 'Infection risk', 'Hospitality employees']
#
# --- Attempting URL 12189/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08603-6
#     Title: Clinical and mycological implications of cryptococcal mening...
#     Abstract found: True (Length: 1748)
#     Keywords found: True (Count: 4) -> ['Cryptococcal meningitis', 'Cryptococcus neoformans', 'Epidemiology', 'Iran']
#
# --- Attempting URL 12190/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)04840-0
#     Title: Application of neutrophil-to-lymphocyte-to-monocyte ratio in...
#     Abstract found: True (Length: 503)
#     Keywords found: True (Count: 4) -> ['Septic shock', 'Prognostic model', 'Mortality predictor', 'Intensive care unit']
#
# --- Attempting URL 12191/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)03117-6
#     Title: Evaluating immunochromatographic test kits for diagnosis of ...
#     Abstract found: True (Length: 622)
#     Keywords found: True (Count: 4) -> ['Acute human leptospirosis', 'Immunochromatographic test', 'Leptospira', 'Leptospirosis']
#
# --- Attempting URL 12192/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09642-7
#     Title: Viral shedding pattern of severe fever with thrombocytopenia...
#     Abstract found: True (Length: 797)
#     Keywords found: True (Count: 5) -> ['Severe fever with thrombocytopenia syndrome virus', 'Dabie bandavirus', 'Viral shedding', 'Precaution measures', 'Human-to-human transmission']
#
# --- Attempting URL 12193/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)15979-8
#     Title: Spatiotemporal distribution, environmental correlation and h...
#     Abstract found: True (Length: 1636)
#     Keywords found: True (Count: 5) -> ['Culex tritaeniorhynchus', 'Spatiotemporal', 'Distribution', 'Environment', 'Urban']
#
# --- Attempting URL 12194/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08591-8
#     Title: Risk factors and prediction model for mortality in HIV/Talar...
#     Abstract found: True (Length: 216)
#     Keywords found: True (Count: 4) -> ['Talaromyces marneffei', 'HIV', 'Risk factors', 'Mortality']
#
# --- Attempting URL 12195/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)01856-4
#     Title: Distribution characteristics of ABO blood groups in China...
#     Abstract found: True (Length: 1379)
#     Keywords found: True (Count: 5) -> ['China population', 'ABO blood group', 'Phenotype', 'Genefrequency', 'Distribution characteristics']
#
# --- Attempting URL 12196/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)08124-0
#     Title: First identification of the SARS-COV-2/XBB.1.5 sublineage am...
#     Abstract found: True (Length: 1623)
#     Keywords found: True (Count: 4) -> ['Severe acute respiratory syndrome Coronavirus-2', 'XBB.1.5 sublineage', 'Influenza sentinel surveillance system', 'Niger']
#
# --- Attempting URL 12197/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)10454-3
#     Title: Immunogenicity and safety of heterologous versus homologous ...
#     Abstract found: True (Length: 554)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 12198/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04633-9
#     Title: Ebola and slum dwellers: Community engagement and epidemic r...
#     Abstract found: True (Length: 1026)
#     Keywords found: True (Count: 6) -> ['Ebola', 'Epidemics', 'West Africa', 'Community engagement', 'Informal settlements']
#
# --- Attempting URL 12199/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10937-1
#     Title: Creating the vaccination improvement potential index...
#     Abstract found: True (Length: 196)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 12200/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10356-8
#     Title: Factors affecting mortality in COVID-19-associated pulmonary...
#     Abstract found: True (Length: 161)
#     Keywords found: True (Count: 4) -> ['COVID-19', 'COVID-19-associated aspergillosis', 'Intensive care unit', 'Mortality']
#
# --- Attempting URL 12201/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08165-9
#     Title: A late-onset hyperammonemia syndrome caused by Ureaplasma pa...
#     Abstract found: True (Length: 1526)
#     Keywords found: True (Count: 5) -> ['Hyperammonemia syndrome', 'Kidney transplantation', 'Ureaplasma parvum', 'Infectious disease', 'Case report']
#
# --- Attempting URL 12202/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)13146-5
#     Title: Differential analysis of lipoprotein and glycoprotein profil...
#     Abstract found: True (Length: 170)
#     Keywords found: True (Count: 6) -> ['Bacterial infections', 'COVID-19', 'Infectious diseases', 'Lipoproteins', 'Metabolism']
#
# --- Attempting URL 12203/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10920-6
#     Title: NH2-MXene/OXG nanocomposite hydrogel with efficient photothe...
#     Abstract found: True (Length: 1034)
#     Keywords found: True (Count: 5) -> ['MXene', 'Hydrogel', 'Photothermal effect', 'NIR', 'Antibacterial activity']
#
# --- Attempting URL 12204/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)08195-7
#     Title: Transmissibility of the variant of concern for SARS-CoV-2 in...
#     Abstract found: True (Length: 295)
#     Keywords found: True (Count: 4) -> ['SARS-CoV-2', 'Period of dominant variants', 'Real-time reproduction number', 'Six regions']
#
# --- Attempting URL 12205/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)05288-5
#     Title: Triglyceride-glucose index predicts sepsis-associated acute ...
#     Abstract found: True (Length: 435)
#     Keywords found: True (Count: 6) -> ['Triglyceride-glucose index', 'Insulin resistance', 'Sepsis', 'Sepsis-associated acute kidney injury', 'Length of stay']
#
# --- Attempting URL 12206/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(22)02928-0
#     Title: Spatial association of Aedes aegypti with dengue fever hotsp...
#     Abstract found: True (Length: 403)
#     Keywords found: True (Count: 7) -> ['Tropical disease', 'Spatial analysis', 'Dengue', 'Hotspot', 'Megacity']
#
# --- Attempting URL 12207/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)09186-7
#     Title: Train-the-trainers intervention for national capacity buildi...
#     Abstract found: True (Length: 499)
#     Keywords found: False (Count: 0) -> []
#
# --- Attempting URL 12208/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)11618-0
#     Title: Relationship between creatinine–cystatin C ratio and all-cau...
#     Abstract found: True (Length: 193)
#     Keywords found: True (Count: 5) -> ['Creatinine', 'Cystatin C', 'Sarcopenia', 'COVID-19', 'Mortality']
#
# --- Attempting URL 12209/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)10660-3
#     Title: Case report: Varicella-zoster virus encephalitis a new type ...
#     Abstract found: True (Length: 320)
#     Keywords found: True (Count: 5) -> ['Varicella-zoster virus', 'Meningoencephalitis', 'Immunosuppression', 'ICU', 'Case report']
#
# --- Attempting URL 12210/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)09262-4
#     Title: Human metapneumovirus infection is associated with a substan...
#     Abstract found: True (Length: 240)
#     Keywords found: True (Count: 4) -> ['Human metapneumovirus', 'Pneumonia', 'Viral pneumonia', 'Respiratory viruses']
#
# --- Attempting URL 12211/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(24)07096-8
#     Title: Clinical profile and parameters of patients monoinfected wit...
#     Abstract found: True (Length: 353)
#     Keywords found: True (Count: 4) -> ['Hepatitis B', 'Hepatitis delta', 'Biomarkers', 'Clinical profile']
#
# --- Attempting URL 12212/12212 (infectious-diseases) ---
#   Navigating to article: https://www.cell.com/heliyon/fulltext/S2405-8440(23)04356-6
#     Title: Multidimensional futuristic approaches to address the pandem...
#     Abstract found: True (Length: 1327)
#     Keywords found: True (Count: 10) -> ['SARS-CoV-2', 'COVID-19', 'Diagnostics', 'Therapeutics', 'RNA mimics Of GFP']

# %%
df = pd.DataFrame(all_collected_data_this_run)
csv_filename = f"heliyon_scraped.csv"
df.to_csv(csv_filename, index=False, encoding='utf-8')
print(f"\nSaved {len(all_collected_data_this_run)} items to '{csv_filename}'")
# Out:
# Saved 9212 items to 'heliyon_scraped.csv'
